# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('job_salary_prediction_dataset.csv')

# %%
df
# Out:
#                  job_title  experience_years education_level  skills_count  \
# 0              AI Engineer                10        Bachelor             2
# 1             Data Analyst                 5        Bachelor            17
# 2       Frontend Developer                18             PhD             4
# 3         Business Analyst                19             PhD            13
# 4          Product Manager                15        Bachelor             7
# ...                    ...               ...             ...           ...
# 249995   Software Engineer                17             PhD             2
# 249996  Frontend Developer                20             PhD             7
# 249997    Business Analyst                 1        Bachelor            12
# 249998      Data Scientist                 0     High School             2
# 249999        Data Analyst                16         Diploma             2
#
#              industry company_size   location remote_work  certifications  \
# 0          Healthcare       Medium      India      Hybrid               2
# 1             Telecom        Small  Australia          No               0
# 2               Media       Medium  Singapore          No               1
# 3              Retail       Medium     Canada         Yes               0
# 4       Manufacturing        Large     Sweden         Yes               0
# ...               ...          ...        ...         ...             ...
# 249995        Telecom   Enterprise      India          No               1
# 249996        Telecom      Startup     Remote          No               2
# 249997         Retail   Enterprise      India         Yes               0
# 249998     Consulting        Small     Sweden      Hybrid               5
# 249999     Technology       Medium         UK          No               5
#
#         salary
# 0       109413
# 1        93764
# 2       148123
# 3       189123
# 4       165069
# ...        ...
# 249995  127791
# 249996  154593
# 249997   75988
# 249998   90467
# 249999  133084
#
# [250000 rows x 10 columns]

# %%
df.shape
# Out:
# (250000, 10)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   job_title         250000 non-null  str
#  1   experience_years  250000 non-null  int64
#  2   education_level   250000 non-null  str
#  3   skills_count      250000 non-null  int64
#  4   industry          250000 non-null  str
#  5   company_size      250000 non-null  str
#  6   location          250000 non-null  str
#  7   remote_work       250000 non-null  str
#  8   certifications    250000 non-null  int64
#  9   salary            250000 non-null  int64
# dtypes: int64(4), str(6)
# memory usage: 19.1 MB

# %%
# Out:
# ============================================================
# Data Types
# ============================================================
# job_title             str
# experience_years    int64
# education_level       str
# skills_count        int64
# industry              str
# company_size          str
# location              str
# remote_work           str
# certifications      int64
# salary              int64
# dtype: object

# %%
print("\n")

print("=" * 60)
print("Missing Values")
print("=" * 60)

print(df.isnull().sum())
# Out:
# ============================================================
# Missing Values
# ============================================================
# job_title           0
# experience_years    0
# education_level     0
# skills_count        0
# industry            0
# company_size        0
# location            0
# remote_work         0
# certifications      0
# salary              0
# dtype: int64

# %%
print("\n")

print("=" * 60)
print("Duplicate Records")
print("=" * 60)

print(df.duplicated().sum())
# Out:
# ============================================================
# Duplicate Records
# ============================================================
# 0

# %%
print("\n")

print("=" * 60)
print("Statistical Summary")
print("=" * 60)

print(df.describe())
# Out:
# ============================================================
# Statistical Summary
# ============================================================
#        experience_years   skills_count  certifications         salary
# count     250000.000000  250000.000000   250000.000000  250000.000000
# mean          10.005408       9.997812        2.491928  145718.080524
# std            6.060602       5.479288        1.706475   37407.952729
# min            0.000000       1.000000        0.000000   31867.000000
# 25%            5.000000       5.000000        1.000000  119358.000000
# 50%           10.000000      10.000000        2.000000  143453.000000
# 75%           15.000000      15.000000        4.000000  169492.000000
# max           20.000000      19.000000        5.000000  333046.000000

# %%
from pandas.api.types import (
    is_string_dtype,
    is_integer_dtype,
    is_float_dtype
)

categorical_columns = []
numerical_columns = []

for col in df.columns:

    if is_string_dtype(df[col]):
        categorical_columns.append(col)

    elif is_integer_dtype(df[col]) or is_float_dtype(df[col]):
        numerical_columns.append(col)

print("\n")

print("=" * 60)
print("Categorical Columns")
print("=" * 60)

print(categorical_columns)
# Out:
# ============================================================
# Categorical Columns
# ============================================================
# ['job_title', 'education_level', 'industry', 'company_size', 'location', 'remote_work']

# %%
for col in categorical_columns:

    print("\n")
    print("=" * 60)
    print(col.upper())
    print("=" * 60)

    print(df[col].value_counts())
# Out:
# ============================================================
# JOB_TITLE
# ============================================================
# job_title
# Backend Developer            21125
# Cybersecurity Analyst        20959
# Product Manager              20950
# AI Engineer                  20945
# Data Scientist               20890
# DevOps Engineer              20889
# Software Engineer            20876
# Data Analyst                 20722
# Cloud Engineer               20686
# Machine Learning Engineer    20677
# Business Analyst             20648
# Frontend Developer           20633
# Name: count, dtype: int64
#
#
# ============================================================
# EDUCATION_LEVEL
# ============================================================
# education_level
# Master         50352
# High School    50065
# Bachelor       49950
# PhD            49857
# Diploma        49776
# Name: count, dtype: int64
#
#
# ============================================================
# INDUSTRY
# ============================================================
# industry
# Finance          25393
# Consulting       25258
# Media            25034
# Manufacturing    25024
# Technology       24903
# Government       24901
# Healthcare       24898
# Education        24889
# Telecom          24859
# Retail           24841
# Name: count, dtype: int64
#
#
# ============================================================
# COMPANY_SIZE
# ============================================================
# company_size
# Large         50254
# Small         50235
# Medium        50027
# Enterprise    49875
# Startup       49609
# Name: count, dtype: int64
#
#
# ============================================================
# LOCATION
# ============================================================
# location
# Australia      25258
# Canada         25165
# Sweden         25100
# Remote         25065
# Singapore      25035
# USA            24931
# UK             24927
# India          24895
# Netherlands    24861
# Germany        24763
# Name: count, dtype: int64
#
#
# ============================================================
# REMOTE_WORK
# ============================================================
# remote_work
# No        83621
# Hybrid    83476
# Yes       82903
# Name: count, dtype: int64

# %%
print("\n")

print("=" * 60)
print("Correlation Matrix")
print("=" * 60)

correlation = df.corr(numeric_only=True)

print(correlation)
# Out:
# ============================================================
# Correlation Matrix
# ============================================================
#                   experience_years  skills_count  certifications    salary
# experience_years          1.000000      0.000149       -0.000198  0.437627
# skills_count              0.000149      1.000000       -0.002230  0.127300
# certifications           -0.000198     -0.002230        1.000000  0.073819
# salary                    0.437627      0.127300        0.073819  1.000000

# %%
print("\n")

print("=" * 60)
print("Correlation Matrix")
print("=" * 60)

correlation = df.corr(numeric_only=True)

print(correlation)
# Out:
# ============================================================
# Correlation Matrix
# ============================================================
#                   experience_years  skills_count  certifications    salary
# experience_years          1.000000      0.000149       -0.000198  0.437627
# skills_count              0.000149      1.000000       -0.002230  0.127300
# certifications           -0.000198     -0.002230        1.000000  0.073819
# salary                    0.437627      0.127300        0.073819  1.000000

# %%
for col in numerical_columns:

    plt.figure(figsize=(7,4))

    sns.histplot(
        df[col],
        kde=True
    )

    plt.title(f"Distribution of {col}")

    plt.show()

# %%
for col in numerical_columns:

    plt.figure(figsize=(7,4))

    sns.histplot(
        df[col],
        kde=True
    )

    plt.title(f"Distribution of {col}")

    plt.show()

# %%
for col in numerical_columns:

    plt.figure(figsize=(7,2))

    sns.boxplot(
        x=df[col]
    )

    plt.title(f"Boxplot of {col}")

    plt.show()

# %%
for col in categorical_columns:

    plt.figure(figsize=(8,4))

    sns.countplot(
        data=df,
        x=col,
        order=df[col].value_counts().index
    )

    plt.xticks(rotation=45)

    plt.title(col)

    plt.show()

# %%
numerical_features = [
    "experience_years",
    "skills_count",
    "certifications"
]

for feature in numerical_features:

    plt.figure(figsize=(7,5))

    sns.scatterplot(
        data=df,
        x=feature,
        y="salary"
    )

    plt.title(f"{feature} vs Salary")

    plt.show()

# %%
sns.pairplot(
    df[
        [
            "experience_years",
            "skills_count",
            "certifications",
            "salary"
        ]
    ]
)

plt.show()

# %%
X = df.drop("salary", axis=1)

# %%
y = df['salary']

# %%
print("\n")

print("=" * 60)
print("Input Features")
print("=" * 60)

print(X.head())

print("\n")

print("=" * 60)
print("Target Variable")
print("=" * 60)

print(y.head())

print("\n")

print("=" * 60)
print("Input Shape")
print("=" * 60)

print(X.shape)

print("\n")
print("=" * 60)
print("Target Shape")
print("=" * 60)

print(y.shape)

print("\n")
# Out:
# ============================================================
# Input Features
# ============================================================
#             job_title  experience_years education_level  skills_count  \
# 0         AI Engineer                10        Bachelor             2
# 1        Data Analyst                 5        Bachelor            17
# 2  Frontend Developer                18             PhD             4
# 3    Business Analyst                19             PhD            13
# 4     Product Manager                15        Bachelor             7
#
#         industry company_size   location remote_work  certifications
# 0     Healthcare       Medium      India      Hybrid               2
# 1        Telecom        Small  Australia          No               0
# 2          Media       Medium  Singapore          No               1
# 3         Retail       Medium     Canada         Yes               0
# 4  Manufacturing        Large     Sweden         Yes               0
#
#
# ============================================================
# Target Variable
# ============================================================
# 0    109413
# 1     93764
# 2    148123
# 3    189123
# 4    165069
# Name: salary, dtype: int64
#
#
# ============================================================
# Input Shape
# ============================================================
# (250000, 9)
#
#
# ============================================================
# Target Shape
# ============================================================
# (250000,)

# %%
df.head()
# Out:
#             job_title  experience_years education_level  skills_count  \
# 0         AI Engineer                10        Bachelor             2
# 1        Data Analyst                 5        Bachelor            17
# 2  Frontend Developer                18             PhD             4
# 3    Business Analyst                19             PhD            13
# 4     Product Manager                15        Bachelor             7
#
#         industry company_size   location remote_work  certifications  salary
# 0     Healthcare       Medium      India      Hybrid               2  109413
# 1        Telecom        Small  Australia          No               0   93764
# 2          Media       Medium  Singapore          No               1  148123
# 3         Retail       Medium     Canada         Yes               0  189123
# 4  Manufacturing        Large     Sweden         Yes               0  165069

# %%
print("="*60)
print("Unique Values in Categorical Columns")
print("="*60)

for col in categorical_columns:

    print(f"\n{col.upper()}")

    print("-"*40)

    print(df[col].unique())

    print(f"\nTotal Unique Values : {df[col].nunique()}")
# Out:
# ============================================================
# Unique Values in Categorical Columns
# ============================================================
#
# JOB_TITLE
# ----------------------------------------
# <StringArray>
# [              'AI Engineer',              'Data Analyst',
#         'Frontend Developer',          'Business Analyst',
#            'Product Manager',         'Backend Developer',
#  'Machine Learning Engineer',           'DevOps Engineer',
#          'Software Engineer',     'Cybersecurity Analyst',
#             'Data Scientist',            'Cloud Engineer']
# Length: 12, dtype: str
#
# Total Unique Values : 12
#
# EDUCATION_LEVEL
# ----------------------------------------
# <StringArray>
# ['Bachelor', 'PhD', 'High School', 'Diploma', 'Master']
# Length: 5, dtype: str
#
# Total Unique Values : 5
#
# INDUSTRY
# ----------------------------------------
# <StringArray>
# [   'Healthcare',       'Telecom',         'Media',        'Retail',
#  'Manufacturing',     'Education',       'Finance',    'Technology',
#     'Consulting',    'Government']
# Length: 10, dtype: str
#
# Total Unique Values : 10
#
# COMPANY_SIZE
# ----------------------------------------
# <StringArray>
# ['Medium', 'Small', 'Large', 'Enterprise', 'Startup']
# Length: 5, dtype: str
#
# Total Unique Values : 5
#
# LOCATION
# ----------------------------------------
# <StringArray>
# [      'India',   'Australia',   'Singapore',      'Canada',      'Sweden',
#          'USA', 'Netherlands',      'Remote',     'Germany',          'UK']
# Length: 10, dtype: str
#
# Total Unique Values : 10
#
# REMOTE_WORK
# ----------------------------------------
# <StringArray>
# ['Hybrid', 'No', 'Yes']
# Length: 3, dtype: str
#
# Total Unique Values : 3

# %%
categorical_features = [
    "job_title",
    "education_level",
    "industry",
    "company_size",
    "location",
    "remote_work"
]

df_encoded = pd.get_dummies(

    df,

    columns=categorical_features,

    drop_first=True

)

print("\n")

print("="*60)
print("Dataset After Encoding")
print("="*60)

print(df_encoded.head())
# Out:
# ============================================================
# Dataset After Encoding
# ============================================================
#    experience_years  skills_count  certifications  salary  \
# 0                10             2               2  109413
# 1                 5            17               0   93764
# 2                18             4               1  148123
# 3                19            13               0  189123
# 4                15             7               0  165069
#
#    job_title_Backend Developer  job_title_Business Analyst  \
# 0                        False                       False
# 1                        False                       False
# 2                        False                       False
# 3                        False                        True
# 4                        False                       False
#
#    job_title_Cloud Engineer  job_title_Cybersecurity Analyst  \
# 0                     False                            False
# 1                     False                            False
# 2                     False                            False
# 3                     False                            False
# 4                     False                            False
#
#    job_title_Data Analyst  job_title_Data Scientist  ...  location_Germany  \
# 0                   False                     False  ...             False
# 1                    True                     False  ...             False
# 2                   False                     False  ...             False
# 3                   False                     False  ...             False
# 4                   False                     False  ...             False
#
#    location_India  location_Netherlands  location_Remote  location_Singapore  \
# 0            True                 False            False               False
# 1           False                 False            False               False
# 2           False                 False            False                True
# 3           False                 False            False               False
# 4           False                 False            False               False
#
#    location_Sweden  location_UK  location_USA  remote_work_No  remote_work_Yes
# 0            False        False         False           False            False
# 1            False        False         False            True            False
# 2            False        False         False            True            False
# 3            False        False         False           False             True
# 4             True        False         False           False             True
#
# [5 rows x 43 columns]

# %%
print("\nEncoded Dataset Shape")

print(df_encoded.shape)
# Out:
# Encoded Dataset Shape
# (250000, 43)

# %%
print("\nData Types After Encoding")

print(df_encoded.dtypes)
# Out:
# Data Types After Encoding
# experience_years                       int64
# skills_count                           int64
# certifications                         int64
# salary                                 int64
# job_title_Backend Developer             bool
# job_title_Business Analyst              bool
# job_title_Cloud Engineer                bool
# job_title_Cybersecurity Analyst         bool
# job_title_Data Analyst                  bool
# job_title_Data Scientist                bool
# job_title_DevOps Engineer               bool
# job_title_Frontend Developer            bool
# job_title_Machine Learning Engineer     bool
# job_title_Product Manager               bool
# job_title_Software Engineer             bool
# education_level_Diploma                 bool
# education_level_High School             bool
# education_level_Master                  bool
# education_level_PhD                     bool
# industry_Education                      bool
# industry_Finance                        bool
# industry_Government                     bool
# industry_Healthcare                     bool
# industry_Manufacturing                  bool
# industry_Media                          bool
# industry_Retail                         bool
# industry_Technology                     bool
# industry_Telecom                        bool
# company_size_Large                      bool
# company_size_Medium                     bool
# company_size_Small                      bool
# company_size_Startup                    bool
# location_Canada                         bool
# location_Germany                        bool
# location_India                          bool
# location_Netherlands                    bool
# location_Remote                         bool
# location_Singapore                      bool
# location_Sweden                         bool
# location_UK                             bool
# location_USA                            bool
# remote_work_No                          bool
# remote_work_Yes                         bool
# dtype: object

# %%
correlation = df_encoded.corr(numeric_only=True)

plt.figure(figsize=(18,12))

sns.heatmap(

    correlation,

    cmap="coolwarm"

)

plt.title("Correlation Matrix After Encoding")

plt.show()

# %%
X = df_encoded.drop("salary", axis=1)

# Target

y = df_encoded["salary"]

print("\n")

print("="*60)
print("Feature Matrix")
print("="*60)

print(X.head())

print("\n")

print("="*60)
print("Target Variable")
print("="*60)

print(y.head())
# Out:
# ============================================================
# Feature Matrix
# ============================================================
#    experience_years  skills_count  certifications  \
# 0                10             2               2
# 1                 5            17               0
# 2                18             4               1
# 3                19            13               0
# 4                15             7               0
#
#    job_title_Backend Developer  job_title_Business Analyst  \
# 0                        False                       False
# 1                        False                       False
# 2                        False                       False
# 3                        False                        True
# 4                        False                       False
#
#    job_title_Cloud Engineer  job_title_Cybersecurity Analyst  \
# 0                     False                            False
# 1                     False                            False
# 2                     False                            False
# 3                     False                            False
# 4                     False                            False
#
#    job_title_Data Analyst  job_title_Data Scientist  \
# 0                   False                     False
# 1                    True                     False
# 2                   False                     False
# 3                   False                     False
# 4                   False                     False
#
#    job_title_DevOps Engineer  ...  location_Germany  location_India  \
# 0                      False  ...             False            True
# 1                      False  ...             False           False
# 2                      False  ...             False           False
# 3                      False  ...             False           False
# 4                      False  ...             False           False
#
#    location_Netherlands  location_Remote  location_Singapore  location_Sweden  \
# 0                 False            False               False            False
# 1                 False            False               False            False
# 2                 False            False                True            False
# 3                 False            False               False            False
# 4                 False            False               False             True
#
#    location_UK  location_USA  remote_work_No  remote_work_Yes
# 0        False         False           False            False
# 1        False         False            True            False
# 2        False         False            True            False
# 3        False         False           False             True
# 4        False         False           False             True
#
# [5 rows x 42 columns]
#
#
# ============================================================
# Target Variable
# ============================================================
# 0    109413
# 1     93764
# 2    148123
# 3    189123
# 4    165069
# Name: salary, dtype: int64

# %%
print("\nTotal Features Used")

print(len(X.columns))

print("\n")

print(X.columns)
# Out:
# Total Features Used
# 42
#
#
# Index(['experience_years', 'skills_count', 'certifications',
#        'job_title_Backend Developer', 'job_title_Business Analyst',
#        'job_title_Cloud Engineer', 'job_title_Cybersecurity Analyst',
#        'job_title_Data Analyst', 'job_title_Data Scientist',
#        'job_title_DevOps Engineer', 'job_title_Frontend Developer',
#        'job_title_Machine Learning Engineer', 'job_title_Product Manager',
#        'job_title_Software Engineer', 'education_level_Diploma',
#        'education_level_High School', 'education_level_Master',
#        'education_level_PhD', 'industry_Education', 'industry_Finance',
#        'industry_Government', 'industry_Healthcare', 'industry_Manufacturing',
#        'industry_Media', 'industry_Retail', 'industry_Technology',
#        'industry_Telecom', 'company_size_Large', 'company_size_Medium',
#        'company_size_Small', 'company_size_Startup', 'location_Canada',
#        'location_Germany', 'location_India', 'location_Netherlands',
#        'location_Remote', 'location_Singapore', 'location_Sweden',
#        'location_UK', 'location_USA', 'remote_work_No', 'remote_work_Yes'],
#       dtype='str')

# %%
from sklearn.model_selection import train_test_split



X_train, X_test, y_train, y_test = train_test_split(

    X,

    y,

    test_size=0.20,

    random_state=42

)

print("\n")

print("="*60)
print("Training Dataset")
print("="*60)

print(X_train.shape)

print(y_train.shape)
print("\n")

print("="*60)
print("Testing Dataset")
print("="*60)

print(X_test.shape)

print(y_test.shape)
# Out:
# ============================================================
# Training Dataset
# ============================================================
# (200000, 42)
# (200000,)
#
#
# ============================================================
# Testing Dataset
# ============================================================
# (50000, 42)
# (50000,)

# %%
print("\n")

print("="*60)
print("Missing Values After Encoding")
print("="*60)

print(X_train.isnull().sum().sum())

print(X_test.isnull().sum().sum())
# Out:
# ============================================================
# Missing Values After Encoding
# ============================================================
# 0
# 0

# %%
print("\n")

print("="*60)
print("Feature Data Types")
print("="*60)

print(X_train.dtypes.unique())
# Out:
# ============================================================
# Feature Data Types
# ============================================================
# [dtype('int64') dtype('bool')]

# %%
print("\n")

print("="*60)
print("Data Preprocessing Completed Successfully")
print("="*60)

print(f"Total Features : {X_train.shape[1]}")

print(f"Training Samples : {X_train.shape[0]}")

print(f"Testing Samples : {X_test.shape[0]}")
# Out:
# ============================================================
# Data Preprocessing Completed Successfully
# ============================================================
# Total Features : 42
# Training Samples : 200000
# Testing Samples : 50000

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(X_train, y_train)

print("="*60)
print("Model Training Completed Successfully")
print("="*60)
# Out:
# ============================================================
# Model Training Completed Successfully
# ============================================================

# %%
print("\nIntercept")

print(model.intercept_)
# Out:
# Intercept
# 146756.0772280439

# %%
print("\nCoefficients")

coefficients = pd.DataFrame({

    "Feature": X_train.columns,

    "Coefficient": model.coef_

})

print(coefficients)
# Out:
# Coefficients
#                                 Feature   Coefficient
# 0                      experience_years   2698.565043
# 1                          skills_count    857.188031
# 2                        certifications   1613.176976
# 3           job_title_Backend Developer -34320.496286
# 4            job_title_Business Analyst -51542.574321
# 5              job_title_Cloud Engineer -21478.447679
# 6       job_title_Cybersecurity Analyst -24685.128457
# 7                job_title_Data Analyst -53759.543499
# 8              job_title_Data Scientist -26901.297907
# 9             job_title_DevOps Engineer -23676.825994
# 10         job_title_Frontend Developer -40887.905471
# 11  job_title_Machine Learning Engineer -10659.873166
# 12            job_title_Product Manager -16125.253719
# 13          job_title_Software Engineer -32290.444015
# 14              education_level_Diploma  -5348.794890
# 15          education_level_High School -10736.701872
# 16               education_level_Master  10829.817459
# 17                  education_level_PhD  21532.269290
# 18                   industry_Education     45.154280
# 19                     industry_Finance     62.148102
# 20                  industry_Government    124.196497
# 21                  industry_Healthcare     83.086089
# 22               industry_Manufacturing    -49.662921
# 23                       industry_Media     81.249254
# 24                      industry_Retail     72.350839
# 25                  industry_Technology     57.249825
# 26                     industry_Telecom     28.566808
# 27                   company_size_Large -14124.660414
# 28                  company_size_Medium -28281.013207
# 29                   company_size_Small -35406.943077
# 30                 company_size_Startup -42399.305090
# 31                      location_Canada  27941.449186
# 32                     location_Germany  13988.379511
# 33                       location_India -41854.458215
# 34                 location_Netherlands    -21.329566
# 35                      location_Remote     -0.416129
# 36                   location_Singapore     22.309338
# 37                      location_Sweden    -42.113186
# 38                          location_UK  20967.211802
# 39                         location_USA  41971.549495
# 40                       remote_work_No      9.380718
# 41                      remote_work_Yes   5338.885135

# %%
train_predictions = model.predict(X_train)

# %%
test_predictions = model.predict(X_test)

# %%
comparison = pd.DataFrame({

    "Actual Salary": y_test.values,

    "Predicted Salary": test_predictions

})

print("\nSample Predictions")

print(comparison.head(10))
# Out:
# Sample Predictions
#    Actual Salary  Predicted Salary
# 0         164009     172850.850756
# 1          79594      89234.518210
# 2          74090      63791.555801
# 3         177193     168311.830872
# 4         120012     117222.932453
# 5         163369     171755.346547
# 6         111889     110424.893725
# 7          75418      60449.433244
# 8         103067      93094.305457
# 9         190692     192448.961434

# %%
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)
train_mae = mean_absolute_error(
    y_train,
    train_predictions
)

train_mse = mean_squared_error(
    y_train,
    train_predictions
)

train_rmse = np.sqrt(train_mse)

train_r2 = r2_score(
    y_train,
    train_predictions
)
test_mae = mean_absolute_error(
    y_test,
    test_predictions
)

test_mse = mean_squared_error(
    y_test,
    test_predictions
)

test_rmse = np.sqrt(test_mse)

test_r2 = r2_score(
    y_test,
    test_predictions
)

print("\n")

print("="*60)
print("Training Performance")
print("="*60)

print(f"MAE  : {train_mae:.2f}")
print(f"MSE  : {train_mse:.2f}")
print(f"RMSE : {train_rmse:.2f}")
print(f"R2   : {train_r2:.4f}")

print("\n")

print("="*60)
print("Testing Performance")
print("="*60)

print(f"MAE  : {test_mae:.2f}")
print(f"MSE  : {test_mse:.2f}")
print(f"RMSE : {test_rmse:.2f}")
print(f"R2   : {test_r2:.4f}")
# Out:
# ============================================================
# Training Performance
# ============================================================
# MAE  : 5470.96
# MSE  : 51359482.66
# RMSE : 7166.55
# R2   : 0.9634
#
#
# ============================================================
# Testing Performance
# ============================================================
# MAE  : 5436.10
# MSE  : 50773076.66
# RMSE : 7125.52
# R2   : 0.9635

# %%
from sklearn.model_selection import cross_val_score

cv_scores = cross_val_score(

    model,

    X,

    y,

    cv=5,

    scoring="r2"

)

print("\n")

print("="*60)
print("Cross Validation")
print("="*60)

print("Individual Scores")

print(cv_scores)

print("\nAverage Score")

print(cv_scores.mean())
# Out:
# ============================================================
# Cross Validation
# ============================================================
# Individual Scores
# [0.96368078 0.96332835 0.96325859 0.96338034 0.96319994]
#
# Average Score
# 0.9633695979784109

# %%
importance = coefficients.copy()

importance["Absolute Coefficient"] = abs(

    importance["Coefficient"]

)

importance = importance.sort_values(

    by="Absolute Coefficient",

    ascending=False

)

print("\n")

print("="*60)
print("Feature Importance")
print("="*60)

print(importance)
# Out:
# ============================================================
# Feature Importance
# ============================================================
#                                 Feature   Coefficient  Absolute Coefficient
# 7                job_title_Data Analyst -53759.543499          53759.543499
# 4            job_title_Business Analyst -51542.574321          51542.574321
# 30                 company_size_Startup -42399.305090          42399.305090
# 39                         location_USA  41971.549495          41971.549495
# 33                       location_India -41854.458215          41854.458215
# 10         job_title_Frontend Developer -40887.905471          40887.905471
# 29                   company_size_Small -35406.943077          35406.943077
# 3           job_title_Backend Developer -34320.496286          34320.496286
# 13          job_title_Software Engineer -32290.444015          32290.444015
# 28                  company_size_Medium -28281.013207          28281.013207
# 31                      location_Canada  27941.449186          27941.449186
# 8              job_title_Data Scientist -26901.297907          26901.297907
# 6       job_title_Cybersecurity Analyst -24685.128457          24685.128457
# 9             job_title_DevOps Engineer -23676.825994          23676.825994
# 17                  education_level_PhD  21532.269290          21532.269290
# 5              job_title_Cloud Engineer -21478.447679          21478.447679
# 38                          location_UK  20967.211802          20967.211802
# 12            job_title_Product Manager -16125.253719          16125.253719
# 27                   company_size_Large -14124.660414          14124.660414
# 32                     location_Germany  13988.379511          13988.379511
# 16               education_level_Master  10829.817459          10829.817459
# 15          education_level_High School -10736.701872          10736.701872
# 11  job_title_Machine Learning Engineer -10659.873166          10659.873166
# 14              education_level_Diploma  -5348.794890           5348.794890
# 41                      remote_work_Yes   5338.885135           5338.885135
# 0                      experience_years   2698.565043           2698.565043
# 2                        certifications   1613.176976           1613.176976
# 1                          skills_count    857.188031            857.188031
# 20                  industry_Government    124.196497            124.196497
# 21                  industry_Healthcare     83.086089             83.086089
# 23                       industry_Media     81.249254             81.249254
# 24                      industry_Retail     72.350839             72.350839
# 19                     industry_Finance     62.148102             62.148102
# 25                  industry_Technology     57.249825             57.249825
# 22               industry_Manufacturing    -49.662921             49.662921
# 18                   industry_Education     45.154280             45.154280
# 37                      location_Sweden    -42.113186             42.113186
# 26                     industry_Telecom     28.566808             28.566808
# 36                   location_Singapore     22.309338             22.309338
# 34                 location_Netherlands    -21.329566             21.329566
# 40                       remote_work_No      9.380718              9.380718
# 35                      location_Remote     -0.416129              0.416129

# %%
top10 = importance.head(10)

plt.figure(figsize=(10,6))

sns.barplot(

    data=top10,

    x="Absolute Coefficient",

    y="Feature"

)

plt.title("Top 10 Important Features")

plt.xlabel("Absolute Coefficient")

plt.ylabel("Feature")

plt.show()

# %%
print("\n")

print("="*60)
print("Multiple Linear Regression Summary")
print("="*60)

print(f"Training Samples      : {len(X_train)}")
print(f"Testing Samples       : {len(X_test)}")

print(f"\nIntercept             : {model.intercept_:.2f}")

print(f"\nTrain R2 Score        : {train_r2:.4f}")

print(f"Test R2 Score         : {test_r2:.4f}")

print(f"Cross Validation R2   : {cv_scores.mean():.4f}")

print(f"Test MAE              : {test_mae:.2f}")

print(f"Test RMSE             : {test_rmse:.2f}")

print("\nModel Trained Successfully!")

print("="*60)
# Out:
# ============================================================
# Multiple Linear Regression Summary
# ============================================================
# Training Samples      : 200000
# Testing Samples       : 50000
#
# Intercept             : 146756.08
#
# Train R2 Score        : 0.9634
# Test R2 Score         : 0.9635
# Cross Validation R2   : 0.9634
# Test MAE              : 5436.10
# Test RMSE             : 7125.52
#
# Model Trained Successfully!
# ============================================================

# %%
plt.figure(figsize=(8,6))

plt.scatter(

    y_test,

    test_predictions,

    alpha=0.6

)

plt.plot(

    [y_test.min(), y_test.max()],

    [y_test.min(), y_test.max()],

    color="red",

    linewidth=2

)

plt.xlabel("Actual Salary")

plt.ylabel("Predicted Salary")

plt.title("Actual vs Predicted Salary")

plt.show()

# %%
residuals = y_test - test_predictions

print("="*60)
print("First 10 Residuals")
print("="*60)

print(residuals.head(10))
# Out:
# ============================================================
# First 10 Residuals
# ============================================================
# 38683     -8841.850756
# 64939     -9640.518210
# 3954      10298.444199
# 120374     8881.169128
# 172861     2789.067547
# 149303    -8386.346547
# 111626     1464.106275
# 164553    14968.566756
# 55779      9972.694543
# 141990    -1756.961434
# Name: salary, dtype: float64

# %%
plt.figure(figsize=(8,6))

plt.scatter(

    test_predictions,

    residuals,

    alpha=0.6

)

plt.axhline(

    y=0,

    color="red",

    linestyle="--"

)

plt.xlabel("Predicted Salary")

plt.ylabel("Residual")

plt.title("Residual Plot")

plt.show()

# %%
import scipy.stats as stats

plt.figure(figsize=(7,7))

stats.probplot(

    residuals,

    dist="norm",

    plot=plt

)

plt.title("QQ Plot")

plt.show()

# %%
print("\nResidual Skewness")

print(residuals.skew())
# Out:
# Residual Skewness
# 0.3679572223482578

# %%
import statsmodels.api as sm

# Add intercept column
X = X.astype(int)

X_sm = sm.add_constant(X)

# Train OLS model

ols_model = sm.OLS(

    y,

    X_sm

).fit()

print("\n")

print("="*60)
print("OLS Regression Summary")
print("="*60)

print(ols_model.summary())
# Out:
# ============================================================
# OLS Regression Summary
# ============================================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 salary   R-squared:                       0.963
# Model:                            OLS   Adj. R-squared:                  0.963
# Method:                 Least Squares   F-statistic:                 1.566e+05
# Date:                Thu, 09 Jul 2026   Prob (F-statistic):               0.00
# Time:                        10:18:01   Log-Likelihood:            -2.5737e+06
# No. Observations:              250000   AIC:                         5.148e+06
# Df Residuals:                  249957   BIC:                         5.148e+06
# Df Model:                          42
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                1.467e+05     99.261   1478.310      0.000    1.47e+05    1.47e+05
# experience_years                     2697.0767      2.363   1141.584      0.000    2692.446    2701.707
# skills_count                          857.9515      2.613    328.308      0.000     852.830     863.073
# certifications                       1615.9013      8.391    192.575      0.000    1599.455    1632.347
# job_title_Backend Developer         -3.441e+04     69.810   -492.900      0.000   -3.45e+04   -3.43e+04
# job_title_Business Analyst          -5.157e+04     70.209   -734.520      0.000   -5.17e+04   -5.14e+04
# job_title_Cloud Engineer            -2.153e+04     70.177   -306.732      0.000   -2.17e+04   -2.14e+04
# job_title_Cybersecurity Analyst     -2.471e+04     69.946   -353.210      0.000   -2.48e+04   -2.46e+04
# job_title_Data Analyst              -5.379e+04     70.147   -766.776      0.000   -5.39e+04   -5.36e+04
# job_title_Data Scientist            -2.693e+04     70.005   -384.654      0.000   -2.71e+04   -2.68e+04
# job_title_DevOps Engineer           -2.377e+04     70.005   -339.551      0.000   -2.39e+04   -2.36e+04
# job_title_Frontend Developer        -4.091e+04     70.222   -582.640      0.000   -4.11e+04   -4.08e+04
# job_title_Machine Learning Engineer -1.073e+04     70.185   -152.851      0.000   -1.09e+04   -1.06e+04
# job_title_Product Manager           -1.617e+04     69.955   -231.095      0.000   -1.63e+04    -1.6e+04
# job_title_Software Engineer         -3.229e+04     70.016   -461.226      0.000   -3.24e+04   -3.22e+04
# education_level_Diploma             -5330.8898     45.341   -117.574      0.000   -5419.757   -5242.023
# education_level_High School         -1.071e+04     45.276   -236.597      0.000   -1.08e+04   -1.06e+04
# education_level_Master               1.081e+04     45.214    239.051      0.000    1.07e+04    1.09e+04
# education_level_PhD                  2.156e+04     45.324    475.623      0.000    2.15e+04    2.16e+04
# industry_Education                     75.7988     63.942      1.185      0.236     -49.526     201.123
# industry_Finance                       55.1192     63.622      0.866      0.386     -69.578     179.817
# industry_Government                   106.2164     63.934      1.661      0.097     -19.093     231.526
# industry_Healthcare                    75.4431     63.936      1.180      0.238     -49.871     200.757
# industry_Manufacturing                 13.0608     63.857      0.205      0.838    -112.098     138.220
# industry_Media                         94.8949     63.848      1.486      0.137     -30.246     220.036
# industry_Retail                        86.2361     63.974      1.348      0.178     -39.151     211.623
# industry_Technology                    60.0424     63.932      0.939      0.348     -65.263     185.348
# industry_Telecom                       45.1733     63.961      0.706      0.480     -80.189     170.536
# company_size_Large                   -1.41e+04     45.251   -311.504      0.000   -1.42e+04    -1.4e+04
# company_size_Medium                 -2.827e+04     45.302   -624.051      0.000   -2.84e+04   -2.82e+04
# company_size_Small                  -3.538e+04     45.255   -781.825      0.000   -3.55e+04   -3.53e+04
# company_size_Startup                -4.237e+04     45.396   -933.291      0.000   -4.25e+04   -4.23e+04
# location_Canada                      2.795e+04     63.765    438.289      0.000    2.78e+04    2.81e+04
# location_Germany                     1.403e+04     64.023    219.143      0.000    1.39e+04    1.42e+04
# location_India                      -4.183e+04     63.938   -654.283      0.000    -4.2e+04   -4.17e+04
# location_Netherlands                  -30.2079     63.960     -0.472      0.637    -155.569      95.153
# location_Remote                        -2.9708     63.829     -0.047      0.963    -128.074     122.133
# location_Singapore                     20.5057     63.848      0.321      0.748    -104.635     145.646
# location_Sweden                       -26.3113     63.806     -0.412      0.680    -151.370      98.747
# location_UK                          2.098e+04     63.917    328.233      0.000    2.09e+04    2.11e+04
# location_USA                         4.194e+04     63.915    656.188      0.000    4.18e+04    4.21e+04
# remote_work_No                         36.2254     35.029      1.034      0.301     -32.431     104.882
# remote_work_Yes                      5354.2810     35.103    152.530      0.000    5285.480    5423.082
# ==============================================================================
# Omnibus:                    12578.005   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            26062.944
# Skew:                           0.354   Prob(JB):                         0.00
# Kurtosis:                       4.414   Cond. No.                         197.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
new_employee = pd.DataFrame(

    [X_train.iloc[0].values],

    columns=X_train.columns

)

predicted_salary = model.predict(new_employee)

print("\n")

print("="*60)
print("Predicted Salary")
print("="*60)

print(predicted_salary)
# Out:
# ============================================================
# Predicted Salary
# ============================================================
# [96868.85020309]

# %%
from joblib import dump

dump(

    model,

    "salary_prediction_model.joblib"

)

print("\nModel Saved Successfully!")
# Out:
# Model Saved Successfully!

# %%
from joblib import load

loaded_model = load(

    "salary_prediction_model.joblib"

)

print("Model Loaded Successfully!")
# Out:
# Model Loaded Successfully!

# %%
print("\n")
print("="*70)
print("Salary Prediction using Multiple Linear Regression")
print("="*70)

print(f"Training Samples           : {len(X_train)}")

print(f"Testing Samples            : {len(X_test)}")

print(f"Total Features             : {X_train.shape[1]}")

print(f"\nIntercept                  : {model.intercept_:.2f}")

print(f"Train R2 Score             : {train_r2:.4f}")

print(f"Test R2 Score              : {test_r2:.4f}")

print(f"Cross Validation Score     : {cv_scores.mean():.4f}")

print(f"Test MAE                   : {test_mae:.2f}")

print(f"Test RMSE                  : {test_rmse:.2f}")

print("\nModel Status : Ready for Deployment")

print("="*70)

print("\nProject Completed Successfully!")
# Out:
# ======================================================================
# Salary Prediction using Multiple Linear Regression
# ======================================================================
# Training Samples           : 200000
# Testing Samples            : 50000
# Total Features             : 42
#
# Intercept                  : 146756.08
# Train R2 Score             : 0.9634
# Test R2 Score              : 0.9635
# Cross Validation Score     : 0.9634
# Test MAE                   : 5436.10
# Test RMSE                  : 7125.52
#
# Model Status : Ready for Deployment
# ======================================================================
#
# Project Completed Successfully!
