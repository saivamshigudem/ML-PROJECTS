# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

import seaborn as sns

import warnings

warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(

    "RELIANCE.csv"

)

print("\n")

print("="*70)

print("Dataset Loaded Successfully")

print("="*70)
# Out:
# ======================================================================
# Dataset Loaded Successfully
# ======================================================================

# %%
print("\n")

print("="*70)

print("First Five Records")

print("="*70)

display(

    df.head()

)
# Out:
# ======================================================================
# First Five Records
# ======================================================================
#          Date    Symbol Series  Prev Close    Open    High     Low    Last  \
# 0  2000-01-03  RELIANCE     EQ      233.05  237.50  251.70  237.50  251.70
# 1  2000-01-04  RELIANCE     EQ      251.70  258.40  271.85  251.30  271.85
# 2  2000-01-05  RELIANCE     EQ      271.85  256.65  287.90  256.65  286.75
# 3  2000-01-06  RELIANCE     EQ      282.50  289.00  300.70  289.00  293.50
# 4  2000-01-07  RELIANCE     EQ      294.35  295.00  317.90  293.00  314.50
#
#     Close    VWAP    Volume      Turnover  Trades  Deliverable Volume  \
# 0  251.70  249.37   4456424  1.111319e+14     NaN                 NaN
# 1  271.85  263.52   9487878  2.500222e+14     NaN                 NaN
# 2  282.50  274.79  26833684  7.373697e+14     NaN                 NaN
# 3  294.35  295.45  15682286  4.633254e+14     NaN                 NaN
# 4  314.55  308.91  19870977  6.138388e+14     NaN                 NaN
#
#    %Deliverble
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
print("\n")

print("="*70)

print("Last Five Records")

print("="*70)

display(

    df.tail()

)
# Out:
# ======================================================================
# Last Five Records
# ======================================================================
#             Date    Symbol Series  Prev Close     Open    High      Low  \
# 5301  2021-04-26  RELIANCE     EQ     1904.35  1920.00  1962.0  1911.50
# 5302  2021-04-27  RELIANCE     EQ     1937.85  1940.00  1997.2  1938.25
# 5303  2021-04-28  RELIANCE     EQ     1988.65  1997.85  2008.0  1980.15
# 5304  2021-04-29  RELIANCE     EQ     1997.30  2022.90  2044.5  2007.30
# 5305  2021-04-30  RELIANCE     EQ     2024.05  2008.50  2036.0  1987.55
#
#          Last    Close     VWAP   Volume      Turnover    Trades  \
# 5301  1938.00  1937.85  1941.32  9620785  1.867699e+15  259137.0
# 5302  1990.00  1988.65  1978.64  9226547  1.825602e+15  291197.0
# 5303  1993.15  1997.30  1997.60  7902002  1.578508e+15  247331.0
# 5304  2020.00  2024.05  2024.21  8035915  1.626634e+15  213153.0
# 5305  1995.90  1994.50  2010.20  9150974  1.839532e+15  288687.0
#
#       Deliverable Volume  %Deliverble
# 5301           4276703.0       0.4445
# 5302           3772144.0       0.4088
# 5303           3921560.0       0.4963
# 5304           2834103.0       0.3527
# 5305           3902504.0       0.4265

# %%
print("\n")

print("="*70)

print("Dataset Shape")

print("="*70)

print(

    "Rows    :",

    df.shape[0]

)

print(

    "Columns :",

    df.shape[1]

)
# Out:
# ======================================================================
# Dataset Shape
# ======================================================================
# Rows    : 5306
# Columns : 15

# %%
print("\n")

print("="*70)

print("Dataset Information")

print("="*70)

df.info()
# Out:
# ======================================================================
# Dataset Information
# ======================================================================
# <class 'pandas.DataFrame'>
# RangeIndex: 5306 entries, 0 to 5305
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                5306 non-null   str
#  1   Symbol              5306 non-null   str
#  2   Series              5306 non-null   str
#  3   Prev Close          5306 non-null   float64
#  4   Open                5306 non-null   float64
#  5   High                5306 non-null   float64
#  6   Low                 5306 non-null   float64
#  7   Last                5306 non-null   float64
#  8   Close               5306 non-null   float64
#  9   VWAP                5306 non-null   float64
#  10  Volume              5306 non-null   int64
#  11  Turnover            5306 non-null   float64
#  12  Trades              2456 non-null   float64
#  13  Deliverable Volume  4792 non-null   float64
#  14  %Deliverble         4792 non-null   float64
# dtypes: float64(11), int64(1), str(3)
# memory usage: 621.9 KB

# %%
print("\n")

print("="*70)

print("Column Names")

print("="*70)

print(

    df.columns.tolist()

)
# Out:
# ======================================================================
# Column Names
# ======================================================================
# ['Date', 'Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last', 'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume', '%Deliverble']

# %%
print("\n")

print("="*70)

print("Statistical Summary")

print("="*70)

display(

    df.describe()

)
# Out:
# ======================================================================
# Statistical Summary
# ======================================================================
#         Prev Close         Open         High          Low         Last  \
# count  5306.000000  5306.000000  5306.000000  5306.000000  5306.000000
# mean   1010.984866  1012.602375  1026.823803   996.886977  1011.157143
# std     570.987079   572.575893   581.986757   560.703328   570.938608
# min     203.200000   205.500000   219.500000   197.150000   203.300000
# 25%     572.137500   572.925000   582.950000   564.237500   572.062500
# 50%     937.950000   939.000000   950.075000   927.550000   939.025000
# 75%    1247.387500  1247.675000  1267.350000  1227.450000  1248.287500
# max    3220.850000  3298.000000  3298.000000  3141.300000  3223.000000
#
#              Close         VWAP        Volume      Turnover        Trades  \
# count  5306.000000  5306.000000  5.306000e+03  5.306000e+03  2.456000e+03
# mean   1011.316839  1011.937409  5.583028e+06  6.076715e+14  1.452306e+05
# std     571.046753   571.222520  4.983793e+06  8.369739e+14  1.297557e+05
# min     203.200000   212.290000  5.282000e+04  4.295543e+12  2.991000e+03
# 25%     572.512500   573.190000  2.836454e+06  2.203354e+14  7.215900e+04
# 50%     938.275000   939.785000  4.213432e+06  3.662999e+14  1.021435e+05
# 75%    1248.275000  1247.375000  6.602604e+06  6.656490e+14  1.686702e+05
# max    3220.850000  3197.750000  6.523089e+07  1.473434e+16  1.428490e+06
#
#        Deliverable Volume  %Deliverble
# count        4.792000e+03  4792.000000
# mean         2.280885e+06     0.435039
# std          1.882665e+06     0.144722
# min          2.909700e+04     0.076300
# 25%          1.194524e+06     0.323325
# 50%          1.810434e+06     0.449450
# 75%          2.752935e+06     0.544300
# max          3.495888e+07     0.978300

# %%
print("\n")

print("="*70)

print("Complete Statistical Summary")

print("="*70)

display(

    df.describe(

        include="all"

    )

)
# Out:
# ======================================================================
# Complete Statistical Summary
# ======================================================================
#               Date    Symbol Series   Prev Close         Open         High  \
# count         5306      5306   5306  5306.000000  5306.000000  5306.000000
# unique        5306         1      1          NaN          NaN          NaN
# top     2000-01-03  RELIANCE     EQ          NaN          NaN          NaN
# freq             1      5306   5306          NaN          NaN          NaN
# mean           NaN       NaN    NaN  1010.984866  1012.602375  1026.823803
# std            NaN       NaN    NaN   570.987079   572.575893   581.986757
# min            NaN       NaN    NaN   203.200000   205.500000   219.500000
# 25%            NaN       NaN    NaN   572.137500   572.925000   582.950000
# 50%            NaN       NaN    NaN   937.950000   939.000000   950.075000
# 75%            NaN       NaN    NaN  1247.387500  1247.675000  1267.350000
# max            NaN       NaN    NaN  3220.850000  3298.000000  3298.000000
#
#                 Low         Last        Close         VWAP        Volume  \
# count   5306.000000  5306.000000  5306.000000  5306.000000  5.306000e+03
# unique          NaN          NaN          NaN          NaN           NaN
# top             NaN          NaN          NaN          NaN           NaN
# freq            NaN          NaN          NaN          NaN           NaN
# mean     996.886977  1011.157143  1011.316839  1011.937409  5.583028e+06
# std      560.703328   570.938608   571.046753   571.222520  4.983793e+06
# min      197.150000   203.300000   203.200000   212.290000  5.282000e+04
# 25%      564.237500   572.062500   572.512500   573.190000  2.836454e+06
# 50%      927.550000   939.025000   938.275000   939.785000  4.213432e+06
# 75%     1227.450000  1248.287500  1248.275000  1247.375000  6.602604e+06
# max     3141.300000  3223.000000  3220.850000  3197.750000  6.523089e+07
#
#             Turnover        Trades  Deliverable Volume  %Deliverble
# count   5.306000e+03  2.456000e+03        4.792000e+03  4792.000000
# unique           NaN           NaN                 NaN          NaN
# top              NaN           NaN                 NaN          NaN
# freq             NaN           NaN                 NaN          NaN
# mean    6.076715e+14  1.452306e+05        2.280885e+06     0.435039
# std     8.369739e+14  1.297557e+05        1.882665e+06     0.144722
# min     4.295543e+12  2.991000e+03        2.909700e+04     0.076300
# 25%     2.203354e+14  7.215900e+04        1.194524e+06     0.323325
# 50%     3.662999e+14  1.021435e+05        1.810434e+06     0.449450
# 75%     6.656490e+14  1.686702e+05        2.752935e+06     0.544300
# max     1.473434e+16  1.428490e+06        3.495888e+07     0.978300

# %%
print("\n")

print("="*70)

print("Missing Values")

print("="*70)

display(

    df.isnull().sum()

)
# Out:
# ======================================================================
# Missing Values
# ======================================================================
# Date                     0
# Symbol                   0
# Series                   0
# Prev Close               0
# Open                     0
# High                     0
# Low                      0
# Last                     0
# Close                    0
# VWAP                     0
# Volume                   0
# Turnover                 0
# Trades                2850
# Deliverable Volume     514
# %Deliverble            514
# dtype: int64

# %%
duplicates = df.duplicated().sum()

print("\n")

print("="*70)

print("Duplicate Records")

print("="*70)

print(

    "Duplicate Records :",

    duplicates

)
# Out:
# ======================================================================
# Duplicate Records
# ======================================================================
# Duplicate Records : 0

# %%
df.drop_duplicates(

    inplace=True

)

print("\n")

print("="*70)

print("Duplicate Records Removed Successfully")

print("="*70)

print(

    "Current Shape :",

    df.shape

)
# Out:
# ======================================================================
# Duplicate Records Removed Successfully
# ======================================================================
# Current Shape : (5306, 15)

# %%
print("\n")

print("="*70)

print("Data Types")

print("="*70)

display(

    df.dtypes

)
# Out:
# ======================================================================
# Data Types
# ======================================================================
# Date                      str
# Symbol                    str
# Series                    str
# Prev Close            float64
# Open                  float64
# High                  float64
# Low                   float64
# Last                  float64
# Close                 float64
# VWAP                  float64
# Volume                  int64
# Turnover              float64
# Trades                float64
# Deliverable Volume    float64
# %Deliverble           float64
# dtype: object

# %%
df["Date"] = pd.to_datetime(

    df["Date"]

)

print("\n")

print("="*70)

print("Date Converted Successfully")

print("="*70)
# Out:
# ======================================================================
# Date Converted Successfully
# ======================================================================

# %%
df = df.sort_values(

    by="Date"

)

print("\n")

print("="*70)

print("Dataset Sorted by Date")

print("="*70)
# Out:
# ======================================================================
# Dataset Sorted by Date
# ======================================================================

# %%
plt.figure(

    figsize=(14,6)

)

plt.plot(

    df["Date"],

    df["Close"]

)

plt.title(

    "Closing Price Trend"

)

plt.xlabel(

    "Date"

)

plt.ylabel(

    "Close Price"

)

plt.grid()

plt.show()

# %%
df["Daily_Return"] = df["Close"].pct_change()

print("\n")

print("="*70)

print("Daily Returns")

print("="*70)

display(

    df[

        [

            "Date",

            "Close",

            "Daily_Return"

        ]

    ].head()

)
# Out:
# ======================================================================
# Daily Returns
# ======================================================================
#         Date   Close  Daily_Return
# 0 2000-01-03  251.70           NaN
# 1 2000-01-04  271.85      0.080056
# 2 2000-01-05  282.50      0.039176
# 3 2000-01-06  294.35      0.041947
# 4 2000-01-07  314.55      0.068626

# %%
plt.figure(

    figsize=(10,5)

)

sns.histplot(

    df["Daily_Return"].dropna(),

    bins=40,

    kde=True

)

plt.title(

    "Daily Return Distribution"

)

plt.xlabel(

    "Daily Return"

)

plt.show()

# %%
plt.figure(

    figsize=(10,5)

)

sns.histplot(

    df["Close"],

    bins=40,

    kde=True

)

plt.title(

    "Closing Price Distribution"

)

plt.xlabel(

    "Closing Price"

)

plt.show()

# %%
plt.figure(

    figsize=(14,5)

)

plt.plot(

    df["Date"],

    df["Volume"]

)

plt.title(

    "Trading Volume"

)

plt.xlabel(

    "Date"

)

plt.ylabel(

    "Volume"

)

plt.grid()

plt.show()

# %%
numeric_df = df.select_dtypes(

    include=np.number

)

plt.figure(

    figsize=(8,6)

)

sns.heatmap(

    numeric_df.corr(),

    annot=True,

    cmap="Blues",

    fmt=".2f"

)

plt.title(

    "Correlation Matrix"

)

plt.show()

# %%
plt.figure(

    figsize=(8,6)

)

sns.scatterplot(

    data=df,

    x="Open",

    y="Close"

)

plt.title(

    "Open Price vs Close Price"

)

plt.show()

# %%
highest_close = df.loc[

    df["Close"].idxmax()

]

print("\n")

print("="*70)

print("Highest Closing Price")

print("="*70)

display(

    highest_close

)
# Out:
# ======================================================================
# Highest Closing Price
# ======================================================================
# Date                  2008-01-14 00:00:00
# Symbol                           RELIANCE
# Series                                 EQ
# Prev Close                         3127.6
# Open                               3159.0
# High                               3240.0
# Low                                3126.0
# Last                               3223.0
# Close                             3220.85
# VWAP                              3197.75
# Volume                            2761350
# Turnover              883010230679999.875
# Trades                                NaN
# Deliverable Volume              1280846.0
# %Deliverble                        0.4638
# Daily_Return                     0.029815
# Name: 2016, dtype: object

# %%
lowest_close = df.loc[

    df["Close"].idxmin()

]

print("\n")

print("="*70)

print("Lowest Closing Price")

print("="*70)

display(

    lowest_close

)
# Out:
# ======================================================================
# Lowest Closing Price
# ======================================================================
# Date                  2000-03-13 00:00:00
# Symbol                           RELIANCE
# Series                                 EQ
# Prev Close                         216.85
# Open                                219.9
# High                                229.5
# Low                                 200.3
# Last                                203.3
# Close                               203.2
# VWAP                               217.37
# Volume                           10765401
# Turnover                234002328445000.0
# Trades                                NaN
# Deliverable Volume                    NaN
# %Deliverble                           NaN
# Daily_Return                    -0.062947
# Name: 49, dtype: object

# %%
print("\n")

print("="*70)

print("Dataset Summary")

print("="*70)

print(

    "Total Records          :",

    df.shape[0]

)

print(

    "Total Features         :",

    df.shape[1]

)

print(

    "Date Range             :",

    df["Date"].min(),

    "to",

    df["Date"].max()

)

print(

    "Highest Closing Price  :",

    round(

        df["Close"].max(),

        2

    )

)

print(

    "Lowest Closing Price   :",

    round(

        df["Close"].min(),

        2

    )

)

print(

    "Average Closing Price  :",

    round(

        df["Close"].mean(),

        2

    )

)

print(

    "Average Daily Volume   :",

    round(

        df["Volume"].mean(),

        2

    )

)

print("="*70)
# Out:
# ======================================================================
# Dataset Summary
# ======================================================================
# Total Records          : 5306
# Total Features         : 16
# Date Range             : 2000-01-03 00:00:00 to 2021-04-30 00:00:00
# Highest Closing Price  : 3220.85
# Lowest Closing Price   : 203.2
# Average Closing Price  : 1011.32
# Average Daily Volume   : 5583027.54
# ======================================================================

# %%
from statsmodels.tsa.stattools import adfuller

from statsmodels.graphics.tsaplots import plot_acf

from statsmodels.graphics.tsaplots import plot_pacf

# %%
print("\n")

print("="*70)

print("Missing Values Before Treatment")

print("="*70)

display(

    df.isnull().sum()

)
# Out:
# ======================================================================
# Missing Values Before Treatment
# ======================================================================
# Date                     0
# Symbol                   0
# Series                   0
# Prev Close               0
# Open                     0
# High                     0
# Low                      0
# Last                     0
# Close                    0
# VWAP                     0
# Volume                   0
# Turnover                 0
# Trades                2850
# Deliverable Volume     514
# %Deliverble            514
# Daily_Return             1
# dtype: int64

# %%
df.ffill(inplace=True)
df.bfill(inplace=True)

print("\n")

print("="*70)

print("Missing Values After Treatment")

print("="*70)

display(

    df.isnull().sum()

)
# Out:
# ======================================================================
# Missing Values After Treatment
# ======================================================================
# Date                  0
# Symbol                0
# Series                0
# Prev Close            0
# Open                  0
# High                  0
# Low                   0
# Last                  0
# Close                 0
# VWAP                  0
# Volume                0
# Turnover              0
# Trades                0
# Deliverable Volume    0
# %Deliverble           0
# Daily_Return          0
# dtype: int64

# %%
duplicates = df.duplicated().sum()

print("\n")

print("="*70)

print("Duplicate Records")

print("="*70)

print(

    "Duplicate Records :",

    duplicates

)

df.drop_duplicates(

    inplace=True

)

print("\n")

print("="*70)

print("Duplicate Records Removed Successfully")

print("="*70)
# Out:
# ======================================================================
# Duplicate Records
# ======================================================================
# Duplicate Records : 0
#
#
# ======================================================================
# Duplicate Records Removed Successfully
# ======================================================================

# %%
df.set_index(

    "Date",

    inplace=True

)

print("\n")

print("="*70)

print("Date Set as Index")

print("="*70)

display(

    df.head()

)
# Out:
# ======================================================================
# Date Set as Index
# ======================================================================
#               Symbol Series  Prev Close    Open    High     Low    Last  \
# Date
# 2000-01-03  RELIANCE     EQ      233.05  237.50  251.70  237.50  251.70
# 2000-01-04  RELIANCE     EQ      251.70  258.40  271.85  251.30  271.85
# 2000-01-05  RELIANCE     EQ      271.85  256.65  287.90  256.65  286.75
# 2000-01-06  RELIANCE     EQ      282.50  289.00  300.70  289.00  293.50
# 2000-01-07  RELIANCE     EQ      294.35  295.00  317.90  293.00  314.50
#
#              Close    VWAP    Volume      Turnover   Trades  \
# Date
# 2000-01-03  251.70  249.37   4456424  1.111319e+14  58630.0
# 2000-01-04  271.85  263.52   9487878  2.500222e+14  58630.0
# 2000-01-05  282.50  274.79  26833684  7.373697e+14  58630.0
# 2000-01-06  294.35  295.45  15682286  4.633254e+14  58630.0
# 2000-01-07  314.55  308.91  19870977  6.138388e+14  58630.0
#
#             Deliverable Volume  %Deliverble  Daily_Return
# Date
# 2000-01-03            221385.0       0.3214      0.080056
# 2000-01-04            221385.0       0.3214      0.080056
# 2000-01-05            221385.0       0.3214      0.039176
# 2000-01-06            221385.0       0.3214      0.041947
# 2000-01-07            221385.0       0.3214      0.068626

# %%
ts = df["Close"]

print("\n")

print("="*70)

print("Time Series Created")

print("="*70)

display(

    ts.head()

)
# Out:
# ======================================================================
# Time Series Created
# ======================================================================
# Date
# 2000-01-03    251.70
# 2000-01-04    271.85
# 2000-01-05    282.50
# 2000-01-06    294.35
# 2000-01-07    314.55
# Name: Close, dtype: float64

# %%
plt.figure(

    figsize=(14,6)

)

plt.plot(

    ts

)

plt.title(

    "Closing Price Time Series"

)

plt.xlabel(

    "Date"

)

plt.ylabel(

    "Closing Price"

)

plt.grid()

plt.show()

# %%
rolling_mean = ts.rolling(

    window=30

).mean()

rolling_std = ts.rolling(

    window=30

).std()

plt.figure(

    figsize=(14,6)

)

plt.plot(

    ts,

    label="Original"

)

plt.plot(

    rolling_mean,

    label="Rolling Mean"

)

plt.plot(

    rolling_std,

    label="Rolling Std"

)

plt.legend()

plt.title(

    "Rolling Mean and Standard Deviation"

)

plt.show()

# %%
print("\n")

print("="*70)

print("ADF Test")

print("="*70)

adf_result = adfuller(

    ts

)

print(

    "ADF Statistic :", adf_result[0]

)

print(

    "p-value :", adf_result[1]

)

print(

    "Critical Values"

)

for key, value in adf_result[4].items():

    print(

        key,

        ":",

        value

    )

if adf_result[1] < 0.05:

    print("\nTime Series is Stationary")

else:

    print("\nTime Series is NOT Stationary")
# Out:
# ======================================================================
# ADF Test
# ======================================================================
# ADF Statistic : -1.8490521097251171
# p-value : 0.3563947012604214
# Critical Values
# 1% : -3.4315879335861528
# 5% : -2.8620870392750826
# 10% : -2.567061188553313
#
# Time Series is NOT Stationary

# %%
ts_diff = ts.diff().dropna()

print("\n")

print("="*70)

print("Differencing Applied")

print("="*70)

display(

    ts_diff.head()

)
# Out:
# ======================================================================
# Differencing Applied
# ======================================================================
# Date
# 2000-01-04    20.15
# 2000-01-05    10.65
# 2000-01-06    11.85
# 2000-01-07    20.20
# 2000-01-10    -6.05
# Name: Close, dtype: float64

# %%
plt.figure(

    figsize=(14,6)

)

plt.plot(

    ts_diff

)

plt.title(

    "Differenced Time Series"

)

plt.grid()

plt.show()

# %%
print("\n")

print("="*70)

print("ADF Test After Differencing")

print("="*70)

adf_diff = adfuller(

    ts_diff

)

print(

    "ADF Statistic :",

    adf_diff[0]

)

print(

    "p-value :",

    adf_diff[1]

)

if adf_diff[1] < 0.05:

    print("\nDifferenced Series is Stationary")

else:

    print("\nDifferenced Series is NOT Stationary")
# Out:
# ======================================================================
# ADF Test After Differencing
# ======================================================================
# ADF Statistic : -16.503016715152242
# p-value : 2.1399848305994165e-29
#
# Differenced Series is Stationary

# %%
plt.figure(

    figsize=(10,5)

)

plot_acf(

    ts_diff,

    lags=40

)

plt.show()

# %%
plt.figure(

    figsize=(10,5)

)

plot_pacf(

    ts_diff,

    lags=40,

    method="ywm"

)

plt.show()

# %%
train_size = int(

    len(ts) * 0.80

)

train = ts.iloc[:train_size]

test = ts.iloc[train_size:]

print("\n")

print("="*70)

print("Train-Test Split")

print("="*70)

print(

    "Training Samples :",

    len(train)

)

print(

    "Testing Samples :",

    len(test)

)
# Out:
# ======================================================================
# Train-Test Split
# ======================================================================
# Training Samples : 4244
# Testing Samples : 1062

# %%
plt.figure(

    figsize=(14,6)

)

plt.plot(

    train,

    label="Train"

)

plt.plot(

    test,

    label="Test"

)

plt.legend()

plt.title(

    "Train and Test Data"

)

plt.grid()

plt.show()

# %%
print("\n")

print("="*70)

print("Dataset Summary")

print("="*70)

print(

    "Total Observations :", len(ts)

)

print(

    "Training Samples   :", len(train)

)

print(

    "Testing Samples    :", len(test)

)

print(

    "ADF p-value        :", round(adf_result[1],6)

)

print(

    "Differenced p-value:", round(adf_diff[1],6)

)

print("\n")

print("Dataset Ready for ARIMA Model")

print("="*70)
# Out:
# ======================================================================
# Dataset Summary
# ======================================================================
# Total Observations : 5306
# Training Samples   : 4244
# Testing Samples    : 1062
# ADF p-value        : 0.356395
# Differenced p-value: 0.0
#
#
# Dataset Ready for ARIMA Model
# ======================================================================

# %%
from statsmodels.tsa.arima.model import ARIMA

from sklearn.metrics import mean_absolute_error

from sklearn.metrics import mean_squared_error

import numpy as np

# %%
model = ARIMA(

    train,

    order=(5,1,0)

)

print("\n")

print("="*70)

print("ARIMA Model Created Successfully")

print("="*70)
# Out:
# ======================================================================
# ARIMA Model Created Successfully
# ======================================================================
# C:\Users\reddy\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\reddy\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\reddy\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
model_fit = model.fit()

print("\n")

print("="*70)

print("Model Training Completed")

print("="*70)
# Out:
# ======================================================================
# Model Training Completed
# ======================================================================

# %%
print("\n")

print("="*70)

print("ARIMA Model Summary")

print("="*70)

print(

    model_fit.summary()

)
# Out:
# ======================================================================
# ARIMA Model Summary
# ======================================================================
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 4244
# Model:                 ARIMA(5, 1, 0)   Log Likelihood              -20727.372
# Date:                Wed, 29 Jul 2026   AIC                          41466.744
# Time:                        11:24:26   BIC                          41504.862
# Sample:                             0   HQIC                         41480.215
#                                - 4244
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0358      0.008      4.609      0.000       0.021       0.051
# ar.L2         -0.0041      0.009     -0.432      0.666      -0.023       0.014
# ar.L3         -0.0815      0.009     -9.451      0.000      -0.098      -0.065
# ar.L4         -0.0282      0.008     -3.462      0.001      -0.044      -0.012
# ar.L5         -0.0417      0.009     -4.751      0.000      -0.059      -0.024
# sigma2      1025.7548      2.072    495.086      0.000    1021.694    1029.816
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):          24502853.44
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.84   Skew:                           -10.15
# Prob(H) (two-sided):                  0.00   Kurtosis:                       374.73
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
forecast = model_fit.forecast(

    steps=len(test)

)

forecast = pd.Series(

    forecast,

    index=test.index

)

print("\n")

print("="*70)

print("Forecast Generated Successfully")

print("="*70)

display(

    forecast.head()

)
# Out:
# ======================================================================
# Forecast Generated Successfully
# ======================================================================
# C:\Users\reddy\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# Date
# 2017-01-13   NaN
# 2017-01-16   NaN
# 2017-01-17   NaN
# 2017-01-18   NaN
# 2017-01-19   NaN
# Name: predicted_mean, dtype: float64

# %%
test = np.nan_to_num(test, nan=0.0)
forecast = np.nan_to_num(forecast, nan=0.0)
mae = mean_absolute_error(

    test,

    forecast

)

mse = mean_squared_error(

    test,

    forecast

)

rmse = np.sqrt(

    mse

)

print("\n")

print("="*70)

print("Evaluation Metrics")

print("="*70)

print(

    "MAE  :",

    round(

        mae,

        4

    )

)

print(

    "MSE  :",

    round(

        mse,

        4

    )

)

print(

    "RMSE :",

    round(

        rmse,

        4

    )

)
# Out:
# ======================================================================
# Evaluation Metrics
# ======================================================================
# MAE  : 1381.0792
# MSE  : 2057490.4285
# RMSE : 1434.3955

# %%
comparison = pd.DataFrame({

    "Actual":

    test,

    "Predicted":

    forecast

})

print("\n")

print("="*70)

print("Actual vs Predicted")

print("="*70)

display(

    comparison.head(20)

)
# Out:
# ======================================================================
# Actual vs Predicted
# ======================================================================
#      Actual  Predicted
# 0   1090.40        0.0
# 1   1076.25        0.0
# 2   1041.25        0.0
# 3   1032.55        0.0
# 4   1033.70        0.0
# 5   1025.80        0.0
# 6   1015.90        0.0
# 7   1027.30        0.0
# 8   1017.30        0.0
# 9   1025.10        0.0
# 10  1044.80        0.0
# 11  1045.20        0.0
# 12  1049.65        0.0
# 13  1043.50        0.0
# 14  1033.65        0.0
# 15  1041.65        0.0
# 16  1030.90        0.0
# 17  1025.15        0.0
# 18  1032.75        0.0
# 19  1030.15        0.0

# %%
plt.figure(

    figsize=(14,6)

)

plt.plot(

    train,

    label="Train"

)

plt.plot(

    test,

    label="Actual"

)

plt.plot(

    forecast,

    label="Forecast"

)

plt.legend()

plt.title(

    "Actual vs Forecast"

)

plt.xlabel(

    "Date"

)

plt.ylabel(

    "Closing Price"

)

plt.grid()

plt.show()

# %%
# Assume your original time series is called 'df' with a Date index
last_date = df.index[-1]   # get last date from the full dataset

future_dates = pd.date_range(
    start=last_date + pd.Timedelta(days=1),
    periods=30,
    freq="D"
)

future_forecast = model_fit.forecast(steps=30)

future_predictions = pd.DataFrame({
    "Date": future_dates,
    "Forecast": future_forecast
})

print("\n")
print("="*70)
print("Next 30 Days Forecast")
print("="*70)
display(future_predictions)
# Out:
# ======================================================================
# Next 30 Days Forecast
# ======================================================================
# C:\Users\reddy\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#            Date     Forecast
# 4244 2021-05-01  1082.251081
# 4245 2021-05-02  1082.077509
# 4246 2021-05-03  1081.900238
# 4247 2021-05-04  1082.216066
# 4248 2021-05-05  1082.386481
# 4249 2021-05-06  1082.454377
# 4250 2021-05-07  1082.442596
# 4251 2021-05-08  1082.426495
# 4252 2021-05-09  1082.402459
# 4253 2021-05-10  1082.393605
# 4254 2021-05-11  1082.392200
# 4255 2021-05-12  1082.395090
# 4256 2021-05-13  1082.397270
# 4257 2021-05-14  1082.398703
# 4258 2021-05-15  1082.398918
# 4259 2021-05-16  1082.398719
# 4260 2021-05-17  1082.398413
# 4261 2021-05-18  1082.398254
# 4262 2021-05-19  1082.398199
# 4263 2021-05-20  1082.398220
# 4264 2021-05-21  1082.398251
# 4265 2021-05-22  1082.398273
# 4266 2021-05-23  1082.398281
# 4267 2021-05-24  1082.398280
# 4268 2021-05-25  1082.398276
# 4269 2021-05-26  1082.398274
# 4270 2021-05-27  1082.398272
# 4271 2021-05-28  1082.398272
# 4272 2021-05-29  1082.398273
# 4273 2021-05-30  1082.398273

# %%
plt.figure(

    figsize=(14,6)

)

plt.plot(

    ts,

    label="Historical"

)

plt.plot(

    future_dates,

    future_forecast,

    label="Future Forecast"

)

plt.legend()

plt.title(

    "Next 30 Days Stock Forecast"

)

plt.xlabel(

    "Date"

)

plt.ylabel(

    "Closing Price"

)

plt.grid()

plt.show()

# %%
residuals = model_fit.resid

print("\n")

print("="*70)

print("Residual Statistics")

print("="*70)

display(

    residuals.describe()

)
# Out:
# ======================================================================
# Residual Statistics
# ======================================================================
# count    4244.000000
# mean        0.278424
# std        32.243864
# min     -1125.371954
# 25%        -7.598242
# 50%         0.351122
# 75%         8.827155
# max       414.219724
# dtype: float64

# %%
plt.figure(

    figsize=(12,5)

)

plt.plot(

    residuals

)

plt.title(

    "Residual Errors"

)

plt.grid()

plt.show()

# %%
plt.figure(

    figsize=(10,5)

)

sns.histplot(

    residuals,

    bins=40,

    kde=True

)

plt.title(

    "Residual Distribution"

)

plt.show()

# %%
print("\n")

print("="*70)

print("Business Insights")

print("="*70)

print("- ARIMA captures historical price trends for forecasting.")

print("- Lower MAE and RMSE indicate better forecasting accuracy.")

print("- Residuals should resemble random noise for a well-fitted model.")

print("- Forecasts assist investors in short-term decision making.")

print("- ARIMA performs best on stationary time series data.")
# Out:
# ======================================================================
# Business Insights
# ======================================================================
# - ARIMA captures historical price trends for forecasting.
# - Lower MAE and RMSE indicate better forecasting accuracy.
# - Residuals should resemble random noise for a well-fitted model.
# - Forecasts assist investors in short-term decision making.
# - ARIMA performs best on stationary time series data.

# %%
print("\n")

print("="*70)

print("ARIMA Model Summary")

print("="*70)

print(

    "Algorithm              : ARIMA"

)

print(

    "Order (p,d,q)          : (5,1,0)"

)

print(

    "Training Samples       :",

    len(train)

)

print(

    "Testing Samples        :",

    len(test)

)

print(

    "MAE                    :",

    round(

        mae,

        4

    )

)

print(

    "MSE                    :",

    round(

        mse,

        4

    )

)

print(

    "RMSE                   :",

    round(

        rmse,

        4

    )

)

print(

    "Forecast Horizon       : 30 Days"

)

print("="*70)
# Out:
# ======================================================================
# ARIMA Model Summary
# ======================================================================
# Algorithm              : ARIMA
# Order (p,d,q)          : (5,1,0)
# Training Samples       : 4244
# Testing Samples        : 1062
# MAE                    : 1381.0792
# MSE                    : 2057490.4285
# RMSE                   : 1434.3955
# Forecast Horizon       : 30 Days
# ======================================================================

# %%
import joblib

# %%
joblib.dump(

    model_fit,

    "arima_stock_model.joblib"

)

print("\n")

print("="*70)

print("ARIMA Model Saved Successfully")

print("="*70)
# Out:
# ======================================================================
# ARIMA Model Saved Successfully
# ======================================================================

# %%
loaded_model = joblib.load(

    "arima_stock_model.joblib"

)

print("\n")

print("="*70)

print("Saved ARIMA Model Loaded Successfully")

print("="*70)
# Out:
# ======================================================================
# Saved ARIMA Model Loaded Successfully
# ======================================================================

# %%
future_forecast = loaded_model.forecast(

    steps=30

)

future_dates = pd.date_range(

    start=ts.index[-1] + pd.Timedelta(days=1),

    periods=30,

    freq="D"

)

forecast_df = pd.DataFrame({

    "Date": future_dates,

    "Forecast_Close_Price": future_forecast

})

print("\n")

print("="*70)

print("Next 30 Days Forecast")

print("="*70)

display(

    forecast_df

)
# Out:
# ======================================================================
# Next 30 Days Forecast
# ======================================================================
# C:\Users\reddy\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#            Date  Forecast_Close_Price
# 4244 2021-05-01           1082.251081
# 4245 2021-05-02           1082.077509
# 4246 2021-05-03           1081.900238
# 4247 2021-05-04           1082.216066
# 4248 2021-05-05           1082.386481
# 4249 2021-05-06           1082.454377
# 4250 2021-05-07           1082.442596
# 4251 2021-05-08           1082.426495
# 4252 2021-05-09           1082.402459
# 4253 2021-05-10           1082.393605
# 4254 2021-05-11           1082.392200
# 4255 2021-05-12           1082.395090
# 4256 2021-05-13           1082.397270
# 4257 2021-05-14           1082.398703
# 4258 2021-05-15           1082.398918
# 4259 2021-05-16           1082.398719
# 4260 2021-05-17           1082.398413
# 4261 2021-05-18           1082.398254
# 4262 2021-05-19           1082.398199
# 4263 2021-05-20           1082.398220
# 4264 2021-05-21           1082.398251
# 4265 2021-05-22           1082.398273
# 4266 2021-05-23           1082.398281
# 4267 2021-05-24           1082.398280
# 4268 2021-05-25           1082.398276
# 4269 2021-05-26           1082.398274
# 4270 2021-05-27           1082.398272
# 4271 2021-05-28           1082.398272
# 4272 2021-05-29           1082.398273
# 4273 2021-05-30           1082.398273

# %%
forecast_df.to_csv(

    "Future_Stock_Forecast.csv",

    index=False

)

print("\n")

print("="*70)

print("Forecast Results Exported Successfully")

print("="*70)
# Out:
# ======================================================================
# Forecast Results Exported Successfully
# ======================================================================

# %%
metrics = pd.DataFrame({

    "Metric":[

        "MAE",

        "MSE",

        "RMSE"

    ],

    "Value":[

        mae,

        mse,

        rmse

    ]

})

metrics.to_csv(

    "Evaluation_Metrics.csv",

    index=False

)

print("\n")

print("="*70)

print("Evaluation Metrics Saved Successfully")

print("="*70)

display(

    metrics

)
# Out:
# ======================================================================
# Evaluation Metrics Saved Successfully
# ======================================================================
#   Metric         Value
# 0    MAE  1.381079e+03
# 1    MSE  2.057490e+06
# 2   RMSE  1.434395e+03

# %%
plt.figure(

    figsize=(14,6)

)

plt.plot(

    ts,

    label="Historical Price"

)

plt.plot(

    future_dates,

    future_forecast,

    label="30-Day Forecast"

)

plt.title(

    "Historical vs Forecasted Stock Prices"

)

plt.xlabel(

    "Date"

)

plt.ylabel(

    "Closing Price"

)

plt.legend()

plt.grid()

plt.show()

# %%
plt.figure(

    figsize=(10,5)

)

plt.plot(

    forecast_df["Date"],

    forecast_df["Forecast_Close_Price"],

    marker="o"

)

plt.title(

    "Forecasted Closing Prices"

)

plt.xlabel(

    "Date"

)

plt.ylabel(

    "Forecast Price"

)

plt.grid()

plt.show()

# %%
model_information = pd.DataFrame({

    "Parameter":[

        "Algorithm",

        "Model",

        "Order (p,d,q)",

        "Training Samples",

        "Testing Samples",

        "Forecast Horizon"

    ],

    "Value":[

        "Time Series Forecasting",

        "ARIMA",

        "(5,1,0)",

        len(train),

        len(test),

        "30 Days"

    ]

})

print("\n")

print("="*70)

print("Model Information")

print("="*70)

display(

    model_information

)
# Out:
# ======================================================================
# Model Information
# ======================================================================
#           Parameter                    Value
# 0         Algorithm  Time Series Forecasting
# 1             Model                    ARIMA
# 2     Order (p,d,q)                  (5,1,0)
# 3  Training Samples                     4244
# 4   Testing Samples                     1062
# 5  Forecast Horizon                  30 Days

# %%
deployment_summary = pd.DataFrame({

    "File":[

        "Trained Model",

        "Future Forecast",

        "Evaluation Metrics"

    ],

    "Saved As":[

        "arima_stock_model.joblib",

        "Future_Stock_Forecast.csv",

        "Evaluation_Metrics.csv"

    ]

})

print("\n")

print("="*70)

print("Deployment Summary")

print("="*70)

display(

    deployment_summary

)
# Out:
# ======================================================================
# Deployment Summary
# ======================================================================
#                  File                   Saved As
# 0       Trained Model   arima_stock_model.joblib
# 1     Future Forecast  Future_Stock_Forecast.csv
# 2  Evaluation Metrics     Evaluation_Metrics.csv

# %%
print("\n")

print("="*70)

print("Business Insights")

print("="*70)

print("- ARIMA captures historical price movements for short-term forecasting.")

print("- Lower MAE, MSE, and RMSE indicate better predictive performance.")

print("- Forecasts can assist analysts in planning and trend analysis.")

print("- Time series models should be retrained regularly with new market data.")

print("- Forecasts should support decisions, not replace risk management.")
# Out:
# ======================================================================
# Business Insights
# ======================================================================
# - ARIMA captures historical price movements for short-term forecasting.
# - Lower MAE, MSE, and RMSE indicate better predictive performance.
# - Forecasts can assist analysts in planning and trend analysis.
# - Time series models should be retrained regularly with new market data.
# - Forecasts should support decisions, not replace risk management.

# %%
print("\n")

print("="*70)

print("Stock Price Forecasting using ARIMA")

print("="*70)

print("Dataset                 : NIFTY 50 Stock Data")

print("Algorithm               : ARIMA")

print("Order (p,d,q)           : (5,1,0)")

print("Training Samples        :", len(train))

print("Testing Samples         :", len(test))

print("Forecast Horizon        : 30 Days")

print("MAE                     :", round(mae,4))

print("MSE                     :", round(mse,4))

print("RMSE                    :", round(rmse,4))

print("Model Saved             : arima_stock_model.joblib")

print("Forecast File           : Future_Stock_Forecast.csv")

print("Metrics File            : Evaluation_Metrics.csv")

print("Project Status          : Deployment Ready")

print("="*70)
# Out:
# ======================================================================
# Stock Price Forecasting using ARIMA
# ======================================================================
# Dataset                 : NIFTY 50 Stock Data
# Algorithm               : ARIMA
# Order (p,d,q)           : (5,1,0)
# Training Samples        : 4244
# Testing Samples         : 1062
# Forecast Horizon        : 30 Days
# MAE                     : 1381.0792
# MSE                     : 2057490.4285
# RMSE                    : 1434.3955
# Model Saved             : arima_stock_model.joblib
# Forecast File           : Future_Stock_Forecast.csv
# Metrics File            : Evaluation_Metrics.csv
# Project Status          : Deployment Ready
# ======================================================================

# %%
print("\n")

print("="*70)

print("Stock Price Forecasting using ARIMA Completed Successfully!")

print("="*70)
# Out:
# ======================================================================
# Stock Price Forecasting using ARIMA Completed Successfully!
# ======================================================================
