# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

import seaborn as sns

import warnings

warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(

    "Groceries_dataset.csv"

)

print("\n")

print("="*70)

print("Dataset Loaded Successfully")

print("="*70)
# Out:
# ======================================================================
# Dataset Loaded Successfully
# ======================================================================

# %%
print("\n")

print("="*70)

print("First Five Records")

print("="*70)

display(

    df.head()

)
# Out:
# ======================================================================
# First Five Records
# ======================================================================
#    Member_number        Date   itemDescription
# 0           1808  21-07-2015    tropical fruit
# 1           2552  05-01-2015        whole milk
# 2           2300  19-09-2015         pip fruit
# 3           1187  12-12-2015  other vegetables
# 4           3037  01-02-2015        whole milk

# %%
print("\n")

print("="*70)

print("Last Five Records")

print("="*70)

display(

    df.tail()

)
# Out:
# ======================================================================
# Last Five Records
# ======================================================================
#        Member_number        Date        itemDescription
# 38760           4471  08-10-2014          sliced cheese
# 38761           2022  23-02-2014                  candy
# 38762           1097  16-04-2014               cake bar
# 38763           1510  03-12-2014  fruit/vegetable juice
# 38764           1521  26-12-2014               cat food

# %%
print("\n")

print("="*70)

print("Dataset Shape")

print("="*70)

print("Rows    :", df.shape[0])

print("Columns :", df.shape[1])
# Out:
# ======================================================================
# Dataset Shape
# ======================================================================
# Rows    : 38765
# Columns : 3

# %%
print("\n")

print("="*70)

print("Dataset Information")

print("="*70)

df.info()
# Out:
# ======================================================================
# Dataset Information
# ======================================================================
# <class 'pandas.DataFrame'>
# RangeIndex: 38765 entries, 0 to 38764
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Member_number    38765 non-null  int64
#  1   Date             38765 non-null  str
#  2   itemDescription  38765 non-null  str
# dtypes: int64(1), str(2)
# memory usage: 908.7 KB

# %%
print("\n")

print("="*70)

print("Column Names")

print("="*70)

print(

    df.columns.tolist()

)
# Out:
# ======================================================================
# Column Names
# ======================================================================
# ['Member_number', 'Date', 'itemDescription']

# %%
print("\n")

print("="*70)

print("Statistical Summary")

print("="*70)

display(

    df.describe()

)
# Out:
# ======================================================================
# Statistical Summary
# ======================================================================
#        Member_number
# count   38765.000000
# mean     3003.641868
# std      1153.611031
# min      1000.000000
# 25%      2002.000000
# 50%      3005.000000
# 75%      4007.000000
# max      5000.000000

# %%
print("\n")

print("="*70)

print("Complete Statistical Summary")

print("="*70)

display(

    df.describe(

        include="all"

    )

)
# Out:
# ======================================================================
# Complete Statistical Summary
# ======================================================================
#         Member_number        Date itemDescription
# count    38765.000000       38765           38765
# unique            NaN         728             167
# top               NaN  21-01-2015      whole milk
# freq              NaN          96            2502
# mean      3003.641868         NaN             NaN
# std       1153.611031         NaN             NaN
# min       1000.000000         NaN             NaN
# 25%       2002.000000         NaN             NaN
# 50%       3005.000000         NaN             NaN
# 75%       4007.000000         NaN             NaN
# max       5000.000000         NaN             NaN

# %%
print("\n")

print("="*70)

print("Missing Values")

print("="*70)

display(

    df.isnull().sum()

)
# Out:
# ======================================================================
# Missing Values
# ======================================================================
# Member_number      0
# Date               0
# itemDescription    0
# dtype: int64

# %%
print("\n")

print("="*70)

print("Missing Values")

print("="*70)

display(

    df.isnull().sum()

)
# Out:
# ======================================================================
# Missing Values
# ======================================================================
# Member_number      0
# Date               0
# itemDescription    0
# dtype: int64

# %%
print("\n")

print("="*70)

print("Duplicate Records")

print("="*70)

duplicates = df.duplicated().sum()

print(

    "Duplicate Records :",

    duplicates

)
# Out:
# ======================================================================
# Duplicate Records
# ======================================================================
# Duplicate Records : 0

# %%
df.drop_duplicates(

    inplace=True

)

print("\n")

print("="*70)

print("Duplicate Records Removed Successfully")

print("="*70)

print(

    "Current Shape :",

    df.shape

)
# Out:
# ======================================================================
# Duplicate Records Removed Successfully
# ======================================================================
# Current Shape : (38006, 3)

# %%
print("\n")

print("="*70)

print("Data Types")

print("="*70)

display(

    df.dtypes

)
# Out:
# ======================================================================
# Data Types
# ======================================================================
# Member_number      int64
# Date                 str
# itemDescription      str
# dtype: object

# %%
print("\n")

print("="*70)

print("Unique Customers")

print("="*70)

print(

    "Unique Customers :",

    df["Member_number"].nunique()

)
# Out:
# ======================================================================
# Unique Customers
# ======================================================================
# Unique Customers : 3898

# %%
print("\n")

print("="*70)

print("Unique Products")

print("="*70)

print(

    "Unique Products :",

    df["itemDescription"].nunique()

)
# Out:
# ======================================================================
# Unique Products
# ======================================================================
# Unique Products : 167

# %%
top_products = df["itemDescription"].value_counts().head(20)

print("\n")

print("="*70)

print("Top 20 Selling Products")

print("="*70)

display(

    top_products

)

plt.figure(

    figsize=(12,6)

)

sns.barplot(

    x=top_products.values,

    y=top_products.index

)

plt.title(

    "Top 20 Selling Products"

)

plt.xlabel(

    "Purchase Count"

)

plt.ylabel(

    "Product"

)

plt.show()
# Out:
# ======================================================================
# Top 20 Selling Products
# ======================================================================
# itemDescription
# whole milk            2363
# other vegetables      1827
# rolls/buns            1646
# soda                  1453
# yogurt                1285
# root vegetables       1041
# tropical fruit        1014
# bottled water          908
# sausage                903
# citrus fruit           795
# pastry                 774
# pip fruit              734
# shopping bags          712
# canned beer            702
# bottled beer           678
# whipped/sour cream     654
# newspapers             582
# frankfurter            565
# brown bread            563
# pork                   555
# Name: count, dtype: int64

# %%
print("\n")

print("="*70)

print("Product Frequency Distribution")

print("="*70)

plt.figure(

    figsize=(10,5)

)

sns.histplot(

    df["itemDescription"].value_counts(),

    bins=30,

    kde=True

)

plt.title(

    "Product Frequency Distribution"

)

plt.xlabel(

    "Frequency"

)

plt.ylabel(

    "Number of Products"

)

plt.show()
# Out:
# ======================================================================
# Product Frequency Distribution
# ======================================================================

# %%
transactions = df.groupby(

    "Member_number"

).size()

print("\n")

print("="*70)

print("Transactions Per Customer")

print("="*70)

display(

    transactions.head()

)

plt.figure(

    figsize=(10,5)

)

sns.histplot(

    transactions,

    bins=30,

    kde=True

)

plt.title(

    "Transactions Per Customer"

)

plt.xlabel(

    "Transactions"

)

plt.ylabel(

    "Customers"

)

plt.show()
# Out:
# ======================================================================
# Transactions Per Customer
# ======================================================================
# Member_number
# 1000    13
# 1001    12
# 1002     8
# 1003     7
# 1004    21
# dtype: int64

# %%
top_customers = df["Member_number"].value_counts().head(10)

print("\n")

print("="*70)

print("Top 10 Active Customers")

print("="*70)

display(

    top_customers

)

plt.figure(

    figsize=(10,5)

)

sns.barplot(

    x=top_customers.index.astype(str),

    y=top_customers.values

)

plt.title(

    "Top 10 Active Customers"

)

plt.xlabel(

    "Customer ID"

)

plt.ylabel(

    "Purchase Count"

)

plt.xticks(

    rotation=45

)

plt.show()
# Out:
# ======================================================================
# Top 10 Active Customers
# ======================================================================
# Member_number
# 3180    35
# 3737    33
# 3050    32
# 2051    31
# 3915    30
# 2625    30
# 2433    30
# 2851    29
# 3872    29
# 2394    29
# Name: count, dtype: int64

# %%
top10 = df["itemDescription"].value_counts().head(10)

plt.figure(

    figsize=(8,8)

)

plt.pie(

    top10.values,

    labels=top10.index,

    autopct="%1.1f%%",

    startangle=90

)

plt.title(

    "Top 10 Product Share"

)

plt.show()

# %%
df["Date"] = pd.to_datetime(

    df["Date"]

)

monthly_sales = df.groupby(

    df["Date"].dt.to_period("M")

).size()

print("\n")

print("="*70)

print("Monthly Purchase Trend")

print("="*70)

display(

    monthly_sales

)

plt.figure(

    figsize=(12,5)

)

monthly_sales.plot(

    marker="o"

)

plt.title(

    "Monthly Purchase Trend"

)

plt.xlabel(

    "Month"

)

plt.ylabel(

    "Transactions"

)

plt.grid()

plt.show()
# Out:
# ======================================================================
# Monthly Purchase Trend
# ======================================================================
# Date
# 2014-01    1499
# 2014-02    1409
# 2014-03    1384
# 2014-04    1533
# 2014-05    1595
# 2014-06    1551
# 2014-07    1557
# 2014-08    1556
# 2014-09    1455
# 2014-10    1576
# 2014-11    1457
# 2014-12    1453
# 2015-01    1751
# 2015-02    1517
# 2015-03    1671
# 2015-04    1661
# 2015-05    1753
# 2015-06    1656
# 2015-07    1683
# 2015-08    1875
# 2015-09    1547
# 2015-10    1627
# 2015-11    1736
# 2015-12    1504
# Freq: M, dtype: int64

# %%
print("\n")

print("="*70)

print("Dataset Summary")

print("="*70)

print(

    "Total Records          :",

    df.shape[0]

)

print(

    "Total Features         :",

    df.shape[1]

)

print(

    "Unique Customers       :",

    df["Member_number"].nunique()

)

print(

    "Unique Products        :",

    df["itemDescription"].nunique()

)

print(

    "Most Sold Product      :",

    df["itemDescription"].mode()[0]

)

print(

    "Duplicate Records      :",

    duplicates

)

print("="*70)
# Out:
# ======================================================================
# Dataset Summary
# ======================================================================
# Total Records          : 38006
# Total Features         : 3
# Unique Customers       : 3898
# Unique Products        : 167
# Most Sold Product      : whole milk
# Duplicate Records      : 0
# ======================================================================

# %%
# %pip install mlxtend
from mlxtend.preprocessing import TransactionEncoder
# Out:
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: C:\Users\reddy\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip
# Collecting mlxtend
#   Downloading mlxtend-0.25.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: scipy>=1.16.3 in c:\users\reddy\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (1.17.1)
# Requirement already satisfied: numpy>=2.3.5 in c:\users\reddy\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (2.4.6)
# Requirement already satisfied: pandas>=2.3.3 in c:\users\reddy\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (3.0.3)
# Requirement already satisfied: scikit-learn>=1.8.0 in c:\users\reddy\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (1.9.0)
# Requirement already satisfied: matplotlib>=3.10.8 in c:\users\reddy\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (3.11.0)
# Requirement already satisfied: joblib>=1.5.2 in c:\users\reddy\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\reddy\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\reddy\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\reddy\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\reddy\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\reddy\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (26.2)
# Requirement already satisfied: pillow>=9 in c:\users\reddy\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\reddy\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\reddy\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\reddy\appdata\local\programs\python\python312\lib\site-packages (from pandas>=2.3.3->mlxtend) (2026.2)
# Requirement already satisfied: narwhals>=2.0.1 in c:\users\reddy\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=1.8.0->mlxtend) (2.22.1)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\users\reddy\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=1.8.0->mlxtend) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\reddy\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.17.0)
# Downloading mlxtend-0.25.0-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    --------------- ------------------------ 0.5/1.4 MB 929.6 kB/s eta 0:00:01
#    ----------------------- ---------------- 0.8/1.4 MB 1.2 MB/s eta 0:00:01
#    ------------------------------ --------- 1.0/1.4 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 1.2 MB/s eta 0:00:00
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.25.0
# Note: you may need to restart the kernel to use updated packages.

# %%
print("\n")

print("="*70)

print("Missing Values Before Treatment")

print("="*70)

display(

    df.isnull().sum()

)
# Out:
# ======================================================================
# Missing Values Before Treatment
# ======================================================================
# Member_number      0
# Date               0
# itemDescription    0
# dtype: int64

# %%
df["itemDescription"].fillna(

    "Unknown",

    inplace=True

)

df["Member_number"].fillna(

    df["Member_number"].mode()[0],

    inplace=True

)

df["Date"].fillna(

    df["Date"].mode()[0],

    inplace=True

)

print("\n")

print("="*70)

print("Missing Values After Treatment")

print("="*70)

display(

    df.isnull().sum()

)
# Out:
# ======================================================================
# Missing Values After Treatment
# ======================================================================
# Member_number      0
# Date               0
# itemDescription    0
# dtype: int64

# %%
duplicates = df.duplicated().sum()

print("\n")

print("="*70)

print("Duplicate Records Before Removal")

print("="*70)

print("Duplicate Records :", duplicates)

df.drop_duplicates(

    inplace=True

)

print("\n")

print("="*70)

print("Duplicate Records Removed Successfully")

print("="*70)

print("Current Shape :", df.shape)
# Out:
# ======================================================================
# Duplicate Records Before Removal
# ======================================================================
# Duplicate Records : 0
#
#
# ======================================================================
# Duplicate Records Removed Successfully
# ======================================================================
# Current Shape : (38006, 3)

# %%
df["Transaction_ID"] = (

    df["Member_number"].astype(str)

    + "_"

    + df["Date"].astype(str)

)

print("\n")

print("="*70)

print("Transaction ID Created Successfully")

print("="*70)

display(

    df[

        [

            "Transaction_ID",

            "itemDescription"

        ]

    ].head()

)
# Out:
# ======================================================================
# Transaction ID Created Successfully
# ======================================================================
#     Transaction_ID   itemDescription
# 0  1808_2015-07-21    tropical fruit
# 1  2552_2015-01-05        whole milk
# 2  2300_2015-09-19         pip fruit
# 3  1187_2015-12-12  other vegetables
# 4  3037_2015-02-01        whole milk

# %%
transactions = df.groupby(

    "Transaction_ID"

)[

    "itemDescription"

].apply(

    list

)

print("\n")

print("="*70)

print("Grouped Transactions")

print("="*70)

display(

    transactions.head()

)
# Out:
# ======================================================================
# Grouped Transactions
# ======================================================================
# Transaction_ID
# 1000_2014-06-24                    [whole milk, pastry, salty snack]
# 1000_2015-03-15    [sausage, whole milk, semi-finished bread, yog...
# 1000_2015-05-27                           [soda, pickled vegetables]
# 1000_2015-07-24                       [canned beer, misc. beverages]
# 1000_2015-11-25                          [sausage, hygiene articles]
# Name: itemDescription, dtype: object

# %%
transaction_list = transactions.tolist()

print("\n")

print("="*70)

print("Transaction List Created")

print("="*70)

print(

    "Total Transactions :",

    len(transaction_list)

)

print("\n")

print("Sample Transaction")

print(transaction_list[0])
# Out:
# ======================================================================
# Transaction List Created
# ======================================================================
# Total Transactions : 14963
#
#
# Sample Transaction
# ['whole milk', 'pastry', 'salty snack']

# %%
encoder = TransactionEncoder()

encoded_array = encoder.fit(

    transaction_list

).transform(

    transaction_list

)

print("\n")

print("="*70)

print("Transaction Encoding Completed")

print("="*70)
# Out:
# ======================================================================
# Transaction Encoding Completed
# ======================================================================

# %%
basket = pd.DataFrame(

    encoded_array,

    columns=encoder.columns_

)

print("\n")

print("="*70)

print("One-Hot Encoded Dataset")

print("="*70)

display(

    basket.head()

)
# Out:
# ======================================================================
# One-Hot Encoded Dataset
# ======================================================================
#    Instant food products  UHT-milk  abrasive cleaner  artif. sweetener  \
# 0                  False     False             False             False
# 1                  False     False             False             False
# 2                  False     False             False             False
# 3                  False     False             False             False
# 4                  False     False             False             False
#
#    baby cosmetics   bags  baking powder  bathroom cleaner   beef  berries  \
# 0           False  False          False             False  False    False
# 1           False  False          False             False  False    False
# 2           False  False          False             False  False    False
# 3           False  False          False             False  False    False
# 4           False  False          False             False  False    False
#
#    ...  turkey  vinegar  waffles  whipped/sour cream  whisky  white bread  \
# 0  ...   False    False    False               False   False        False
# 1  ...   False    False    False               False   False        False
# 2  ...   False    False    False               False   False        False
# 3  ...   False    False    False               False   False        False
# 4  ...   False    False    False               False   False        False
#
#    white wine  whole milk  yogurt  zwieback
# 0       False        True   False     False
# 1       False        True    True     False
# 2       False       False   False     False
# 3       False       False   False     False
# 4       False       False   False     False
#
# [5 rows x 167 columns]

# %%
print("\n")

print("="*70)

print("Encoded Dataset Shape")

print("="*70)

print("Rows    :", basket.shape[0])

print("Columns :", basket.shape[1])
# Out:
# ======================================================================
# Encoded Dataset Shape
# ======================================================================
# Rows    : 14963
# Columns : 167

# %%
product_frequency = basket.sum().sort_values(

    ascending=False

)

print("\n")

print("="*70)

print("Top 20 Frequently Purchased Products")

print("="*70)

display(

    product_frequency.head(20)

)
# Out:
# ======================================================================
# Top 20 Frequently Purchased Products
# ======================================================================
# whole milk            2363
# other vegetables      1827
# rolls/buns            1646
# soda                  1453
# yogurt                1285
# root vegetables       1041
# tropical fruit        1014
# bottled water          908
# sausage                903
# citrus fruit           795
# pastry                 774
# pip fruit              734
# shopping bags          712
# canned beer            702
# bottled beer           678
# whipped/sour cream     654
# newspapers             582
# frankfurter            565
# brown bread            563
# domestic eggs          555
# dtype: int64

# %%
plt.figure(

    figsize=(12,6)

)

sns.barplot(

    x=product_frequency.head(20).values,

    y=product_frequency.head(20).index

)

plt.title(

    "Top 20 Purchased Products"

)

plt.xlabel(

    "Purchase Frequency"

)

plt.ylabel(

    "Products"

)

plt.show()

# %%
transaction_size = basket.sum(

    axis=1

)

print("\n")

print("="*70)

print("Transaction Size Statistics")

print("="*70)

display(

    transaction_size.describe()

)

plt.figure(

    figsize=(10,5)

)

sns.histplot(

    transaction_size,

    bins=20,

    kde=True

)

plt.title(

    "Items Per Transaction"

)

plt.xlabel(

    "Number of Items"

)

plt.ylabel(

    "Transactions"

)

plt.show()
# Out:
# ======================================================================
# Transaction Size Statistics
# ======================================================================
# count    14963.000000
# mean         2.539999
# std          1.060993
# min          1.000000
# 25%          2.000000
# 50%          2.000000
# 75%          3.000000
# max         10.000000
# dtype: float64

# %%
total_cells = basket.shape[0] * basket.shape[1]

filled_cells = basket.values.sum()

sparsity = (

    1 -

    (filled_cells / total_cells)

) * 100

print("\n")

print("="*70)

print("Dataset Sparsity")

print("="*70)

print(

    "Sparsity :",

    round(

        sparsity,

        2

    ),

    "%"

)
# Out:
# ======================================================================
# Dataset Sparsity
# ======================================================================
# Sparsity : 98.48 %

# %%
print("\n")

print("="*70)

print("Boolean Matrix Verification")

print("="*70)

display(

    basket.dtypes.head()

)
# Out:
# ======================================================================
# Boolean Matrix Verification
# ======================================================================
# Instant food products    bool
# UHT-milk                 bool
# abrasive cleaner         bool
# artif. sweetener         bool
# baby cosmetics           bool
# dtype: object

# %%
print("\n")

print("="*70)

print("Dataset Summary")

print("="*70)

print(

    "Transactions             :",

    basket.shape[0]

)

print(

    "Products                 :",

    basket.shape[1]

)

print(

    "Most Purchased Product   :",

    product_frequency.idxmax()

)

print(

    "Highest Purchase Count   :",

    product_frequency.max()

)

print(

    "Average Basket Size      :",

    round(

        transaction_size.mean(),

        2

    )

)

print(

    "Dataset Sparsity (%)     :",

    round(

        sparsity,

        2

    )

)

print("\n")

print("Dataset Ready for Apriori Algorithm")

print("="*70)
# Out:
# ======================================================================
# Dataset Summary
# ======================================================================
# Transactions             : 14963
# Products                 : 167
# Most Purchased Product   : whole milk
# Highest Purchase Count   : 2363
# Average Basket Size      : 2.54
# Dataset Sparsity (%)     : 98.48
#
#
# Dataset Ready for Apriori Algorithm
# ======================================================================

# %%
from mlxtend.frequent_patterns import apriori

from mlxtend.frequent_patterns import association_rules

# %%
frequent_itemsets = apriori(

    basket,

    min_support=0.01,

    use_colnames=True

)

print("\n")

print("="*70)

print("Frequent Itemsets Generated Successfully")

print("="*70)

display(

    frequent_itemsets.head()

)
# Out:
# ======================================================================
# Frequent Itemsets Generated Successfully
# ======================================================================
#     support                   itemsets
# 0  0.021386      frozenset({UHT-milk})
# 1  0.033950          frozenset({beef})
# 2  0.021787       frozenset({berries})
# 3  0.016574     frozenset({beverages})
# 4  0.045312  frozenset({bottled beer})

# %%
print("\n")

print("="*70)

print("Frequent Itemsets Summary")

print("="*70)

print(

    "Total Frequent Itemsets :",

    len(frequent_itemsets)

)
# Out:
# ======================================================================
# Frequent Itemsets Summary
# ======================================================================
# Total Frequent Itemsets : 69

# %%
top_itemsets = frequent_itemsets.sort_values(

    by="support",

    ascending=False

)

print("\n")

print("="*70)

print("Top 20 Frequent Itemsets")

print("="*70)

display(

    top_itemsets.head(20)

)
# Out:
# ======================================================================
# Top 20 Frequent Itemsets
# ======================================================================
#      support                         itemsets
# 62  0.157923          frozenset({whole milk})
# 40  0.122101    frozenset({other vegetables})
# 46  0.110005          frozenset({rolls/buns})
# 52  0.097106                frozenset({soda})
# 63  0.085879              frozenset({yogurt})
# 47  0.069572     frozenset({root vegetables})
# 57  0.067767      frozenset({tropical fruit})
# 5   0.060683       frozenset({bottled water})
# 49  0.060349             frozenset({sausage})
# 15  0.053131        frozenset({citrus fruit})
# 41  0.051728              frozenset({pastry})
# 42  0.049054           frozenset({pip fruit})
# 50  0.047584       frozenset({shopping bags})
# 10  0.046916         frozenset({canned beer})
# 4   0.045312        frozenset({bottled beer})
# 59  0.043708  frozenset({whipped/sour cream})
# 37  0.038896          frozenset({newspapers})
# 21  0.037760         frozenset({frankfurter})
# 6   0.037626         frozenset({brown bread})
# 43  0.037091                frozenset({pork})

# %%
plt.figure(

    figsize=(12,6)

)

plt.bar(

    range(20),

    top_itemsets.head(20)["support"]

)

plt.xticks(

    range(20),

    [

        ", ".join(item)

        for item in top_itemsets.head(20)["itemsets"]

    ],

    rotation=90

)

plt.title(

    "Top 20 Frequent Itemsets"

)

plt.ylabel(

    "Support"

)

plt.show()

# %%
# Step 1: Load dataset
groceries = pd.read_csv("Groceries_dataset.csv")

# Step 2: Create basket (pivot table)
basket = pd.crosstab(groceries['Member_number'], groceries['itemDescription'])

# Step 3: Convert counts to boolean (saves memory vs int)
basket = (basket > 0)

# Step 4: Run fpgrowth (more memory-efficient than apriori)
# Adjust min_support to balance between too few and too many itemsets
frequent_itemsets = fpgrowth(basket, min_support=0.02, use_colnames=True, max_len=2)

print("\n")
print("="*70)
print("Frequent Itemsets Generated Successfully")
print("="*70)
print(frequent_itemsets.head())

# Step 5: Generate association rules
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.3)

print("\n")
print("="*70)
print("Association Rules Generated Successfully")
print("="*70)
print(rules.head())
# Out:
# ======================================================================
# Frequent Itemsets Generated Successfully
# ======================================================================
#     support                 itemsets
# 0  0.458184  frozenset({whole milk})
# 1  0.313494        frozenset({soda})
# 2  0.282966      frozenset({yogurt})
# 3  0.206003     frozenset({sausage})
# 4  0.177527      frozenset({pastry})
#
#
# ======================================================================
# Association Rules Generated Successfully
# ======================================================================
#                antecedents                    consequents  antecedent support  \
# 0        frozenset({soda})        frozenset({whole milk})            0.313494
# 1  frozenset({whole milk})              frozenset({soda})            0.458184
# 2        frozenset({soda})        frozenset({rolls/buns})            0.313494
# 3  frozenset({rolls/buns})              frozenset({soda})            0.349666
# 4        frozenset({soda})  frozenset({other vegetables})            0.313494
#
#    consequent support   support  confidence      lift  representativity  \
# 0            0.458184  0.151103    0.481997  1.051973               1.0
# 1            0.313494  0.151103    0.329787  1.051973               1.0
# 2            0.349666  0.119805    0.382160  1.092928               1.0
# 3            0.313494  0.119805    0.342627  1.092928               1.0
# 4            0.376603  0.124166    0.396072  1.051695               1.0
#
#    leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0  0.007465    1.045971       0.071966  0.243489   0.043950    0.405892
# 1  0.007465    1.024310       0.091184  0.243489   0.023733    0.405892
# 2  0.010187    1.052593       0.123855  0.220491   0.049965    0.362393
# 3  0.010187    1.044316       0.130743  0.220491   0.042436    0.362393
# 4  0.006103    1.032237       0.071601  0.219402   0.031230    0.362886

# %%
print("\n")

print("="*70)

print("Association Rules Generated Successfully")

print("="*70)

display(

    rules.head()

)
# Out:
# ======================================================================
# Association Rules Generated Successfully
# ======================================================================
#                antecedents                    consequents  antecedent support  \
# 0        frozenset({soda})        frozenset({whole milk})            0.313494
# 1  frozenset({whole milk})              frozenset({soda})            0.458184
# 2        frozenset({soda})        frozenset({rolls/buns})            0.313494
# 3  frozenset({rolls/buns})              frozenset({soda})            0.349666
# 4        frozenset({soda})  frozenset({other vegetables})            0.313494
#
#    consequent support   support  confidence      lift  representativity  \
# 0            0.458184  0.151103    0.481997  1.051973               1.0
# 1            0.313494  0.151103    0.329787  1.051973               1.0
# 2            0.349666  0.119805    0.382160  1.092928               1.0
# 3            0.313494  0.119805    0.342627  1.092928               1.0
# 4            0.376603  0.124166    0.396072  1.051695               1.0
#
#    leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0  0.007465    1.045971       0.071966  0.243489   0.043950    0.405892
# 1  0.007465    1.024310       0.091184  0.243489   0.023733    0.405892
# 2  0.010187    1.052593       0.123855  0.220491   0.049965    0.362393
# 3  0.010187    1.044316       0.130743  0.220491   0.042436    0.362393
# 4  0.006103    1.032237       0.071601  0.219402   0.031230    0.362886

# %%
top_confidence = rules.sort_values(

    by="confidence",

    ascending=False

)

print("\n")

print("="*70)

print("Top 20 Rules by Confidence")

print("="*70)

display(

    top_confidence.head(20)

)
# Out:
# ======================================================================
# Top 20 Rules by Confidence
# ======================================================================
#                         antecedents                    consequents  \
# 251                frozenset({ham})        frozenset({whole milk})
# 272        frozenset({chewing gum})        frozenset({whole milk})
# 161     frozenset({hamburger meat})        frozenset({whole milk})
# 87               frozenset({sugar})        frozenset({whole milk})
# 270           frozenset({cat food})        frozenset({whole milk})
# 123          frozenset({chocolate})        frozenset({whole milk})
# 267            frozenset({waffles})        frozenset({whole milk})
# 271           frozenset({cat food})  frozenset({other vegetables})
# 213               frozenset({meat})        frozenset({whole milk})
# 207   frozenset({processed cheese})        frozenset({whole milk})
# 229                frozenset({oil})        frozenset({whole milk})
# 194              frozenset({candy})        frozenset({whole milk})
# 118      frozenset({shopping bags})        frozenset({whole milk})
# 128     frozenset({red/blush wine})        frozenset({whole milk})
# 247      frozenset({cream cheese })        frozenset({whole milk})
# 139       frozenset({bottled beer})        frozenset({whole milk})
# 65         frozenset({white bread})        frozenset({whole milk})
# 82   frozenset({frozen vegetables})        frozenset({whole milk})
# 60                frozenset({beef})        frozenset({whole milk})
# 262          frozenset({ice cream})        frozenset({whole milk})
#
#      antecedent support  consequent support   support  confidence      lift  \
# 251            0.063366            0.458184  0.036942    0.582996  1.272407
# 272            0.044638            0.458184  0.025654    0.574713  1.254328
# 161            0.080298            0.458184  0.045408    0.565495  1.234211
# 87             0.065931            0.458184  0.036942    0.560311  1.222897
# 270            0.043869            0.458184  0.024371    0.555556  1.212517
# 123            0.086455            0.458184  0.047973    0.554896  1.211078
# 267            0.069010            0.458184  0.037968    0.550186  1.200798
# 271            0.043869            0.376603  0.024115    0.549708  1.459646
# 213            0.063622            0.458184  0.034890    0.548387  1.196872
# 207            0.038481            0.458184  0.021036    0.546667  1.193117
# 229            0.055670            0.458184  0.030272    0.543779  1.186814
# 194            0.053874            0.458184  0.029246    0.542857  1.184802
# 118            0.168291            0.458184  0.091329    0.542683  1.184422
# 128            0.039764            0.458184  0.021550    0.541935  1.182791
# 247            0.088507            0.458184  0.047717    0.539130  1.176669
# 139            0.158799            0.458184  0.085428    0.537964  1.174124
# 65             0.088763            0.458184  0.047717    0.537572  1.173268
# 82             0.102617            0.458184  0.055156    0.537500  1.173110
# 60             0.119548            0.458184  0.064135    0.536481  1.170886
# 262            0.056439            0.458184  0.030272    0.536364  1.170630
#
#      representativity  leverage  conviction  zhangs_metric   jaccard  \
# 251               1.0  0.007909    1.299307       0.228571  0.076231
# 272               1.0  0.005202    1.274001       0.212234  0.053763
# 161               1.0  0.008617    1.246974       0.206334  0.092092
# 87                1.0  0.006733    1.232273       0.195135  0.075829
# 270               1.0  0.004272    1.219087       0.183311  0.051020
# 123               1.0  0.008361    1.217281       0.190783  0.096591
# 267               1.0  0.006349    1.204534       0.179615  0.077609
# 271               1.0  0.007594    1.384426       0.329351  0.060841
# 213               1.0  0.005739    1.199736       0.175665  0.071654
# 207               1.0  0.003405    1.195183       0.168337  0.044229
# 229               1.0  0.004765    1.187618       0.166687  0.062599
# 194               1.0  0.004562    1.185223       0.164859  0.060574
# 118               1.0  0.014220    1.184772       0.187213  0.170662
# 128               1.0  0.003330    1.182838       0.160942  0.045234
# 247               1.0  0.007164    1.175639       0.164722  0.095630
# 139               1.0  0.012669    1.172672       0.176297  0.160714
# 65                1.0  0.007047    1.171678       0.162065  0.095581
# 82                1.0  0.008139    1.171495       0.164439  0.109082
# 60                1.0  0.009360    1.168919       0.165762  0.124875
# 262               1.0  0.004412    1.168623       0.154478  0.062500
#
#      certainty  kulczynski
# 251   0.230359    0.331812
# 272   0.215071    0.315352
# 161   0.198059    0.332300
# 87    0.188491    0.320469
# 270   0.179714    0.304374
# 123   0.178497    0.329800
# 267   0.169803    0.316526
# 271   0.277679    0.306870
# 213   0.166483    0.312267
# 207   0.163308    0.296290
# 229   0.157978    0.304924
# 194   0.156277    0.303343
# 118   0.155956    0.371006
# 128   0.154576    0.294484
# 247   0.149399    0.321637
# 139   0.147247    0.362207
# 65    0.146523    0.320858
# 82    0.146390    0.328940
# 60    0.144508    0.338229
# 262   0.144292    0.301217

# %%
top_lift = rules.sort_values(

    by="lift",

    ascending=False

)

print("\n")

print("="*70)

print("Top 20 Rules by Lift")

print("="*70)

display(

    top_lift.head(20)

)
# Out:
# ======================================================================
# Top 20 Rules by Lift
# ======================================================================
#                             antecedents                    consequents  \
# 92                   frozenset({sugar})           frozenset({sausage})
# 271               frozenset({cat food})  frozenset({other vegetables})
# 91                   frozenset({sugar})     frozenset({bottled water})
# 244              frozenset({beverages})              frozenset({soda})
# 223  frozenset({fruit/vegetable juice})   frozenset({root vegetables})
# 178               frozenset({UHT-milk})  frozenset({other vegetables})
# 127              frozenset({chocolate})            frozenset({yogurt})
# 266                frozenset({waffles})    frozenset({tropical fruit})
# 32             frozenset({salty snack})   frozenset({root vegetables})
# 16                 frozenset({sausage})            frozenset({yogurt})
# 58                    frozenset({curd})    frozenset({tropical fruit})
# 108           frozenset({frozen meals})        frozenset({rolls/buns})
# 218            frozenset({hard cheese})  frozenset({other vegetables})
# 251                    frozenset({ham})        frozenset({whole milk})
# 230                    frozenset({oil})            frozenset({yogurt})
# 90                   frozenset({sugar})              frozenset({soda})
# 80                  frozenset({butter})            frozenset({yogurt})
# 272            frozenset({chewing gum})        frozenset({whole milk})
# 210                frozenset({napkins})        frozenset({rolls/buns})
# 159         frozenset({hamburger meat})            frozenset({yogurt})
#
#      antecedent support  consequent support   support  confidence      lift  \
# 92             0.065931            0.206003  0.020523    0.311284  1.511065
# 271            0.043869            0.376603  0.024115    0.549708  1.459646
# 91             0.065931            0.213699  0.020010    0.303502  1.420229
# 244            0.062083            0.313494  0.026167    0.421488  1.344483
# 223            0.124936            0.230631  0.038738    0.310062  1.344405
# 178            0.078502            0.376603  0.038994    0.496732  1.318979
# 127            0.086455            0.282966  0.032068    0.370920  1.310830
# 266            0.069010            0.233710  0.021036    0.304833  1.304323
# 32             0.069266            0.230631  0.020780    0.300000  1.300779
# 16             0.206003            0.282966  0.075423    0.366127  1.293892
# 58             0.120831            0.233710  0.036429    0.301486  1.290004
# 108            0.062853            0.349666  0.028220    0.448980  1.284022
# 218            0.053361            0.376603  0.025654    0.480769  1.276593
# 251            0.063366            0.458184  0.036942    0.582996  1.272407
# 230            0.055670            0.282966  0.020010    0.359447  1.270285
# 90             0.065931            0.313494  0.026167    0.396887  1.266012
# 80             0.126475            0.282966  0.044895    0.354970  1.254462
# 272            0.044638            0.458184  0.025654    0.574713  1.254328
# 210            0.081324            0.349666  0.035659    0.438486  1.254011
# 159            0.080298            0.282966  0.028476    0.354633  1.253271
#
#      representativity  leverage  conviction  zhangs_metric   jaccard  \
# 92                1.0  0.006941    1.152866       0.362088  0.081633
# 271               1.0  0.007594    1.384426       0.329351  0.060841
# 91                1.0  0.005921    1.128934       0.316773  0.077075
# 244               1.0  0.006705    1.186674       0.273180  0.074890
# 223               1.0  0.009924    1.115127       0.292752  0.122267
# 178               1.0  0.009430    1.238697       0.262440  0.093711
# 127               1.0  0.007604    1.139814       0.259565  0.095057
# 266               1.0  0.004908    1.102311       0.250613  0.074681
# 32                1.0  0.004805    1.099098       0.248438  0.074449
# 16                1.0  0.017132    1.131196       0.286069  0.182382
# 58                1.0  0.008190    1.097030       0.255706  0.114516
# 108               1.0  0.006242    1.180235       0.236033  0.073431
# 218               1.0  0.005558    1.200616       0.228878  0.063452
# 251               1.0  0.007909    1.299307       0.228571  0.076231
# 230               1.0  0.004258    1.119399       0.225319  0.062802
# 90                1.0  0.005498    1.138271       0.224949  0.074074
# 80                1.0  0.009107    1.111629       0.232215  0.123153
# 272               1.0  0.005202    1.274001       0.212234  0.053763
# 210               1.0  0.007223    1.158178       0.220490  0.090201
# 159               1.0  0.005755    1.111048       0.219732  0.085057
#
#      certainty  kulczynski
# 92    0.132596    0.205455
# 271   0.277679    0.306870
# 91    0.114209    0.198570
# 244   0.157309    0.252479
# 223   0.103241    0.239013
# 178   0.192700    0.300137
# 127   0.122664    0.242124
# 266   0.092815    0.197422
# 32    0.090163    0.195050
# 16    0.115980    0.316336
# 58    0.088448    0.228679
# 108   0.152711    0.264842
# 218   0.167094    0.274445
# 251   0.230359    0.331812
# 230   0.106663    0.215082
# 90    0.121475    0.240178
# 80    0.100419    0.256814
# 272   0.215071    0.315352
# 210   0.136575    0.270233
# 159   0.099949    0.227634

# %%
plt.figure(

    figsize=(10,6)

)

sns.scatterplot(

    data=rules,

    x="support",

    y="confidence",

    size="lift",

    hue="lift",

    sizes=(20,300)

)

plt.title(

    "Support vs Confidence"

)

plt.show()

# %%
plt.figure(

    figsize=(10,5)

)

sns.histplot(

    rules["lift"],

    bins=30,

    kde=True

)

plt.title(

    "Lift Distribution"

)

plt.xlabel(

    "Lift"

)

plt.ylabel(

    "Frequency"

)

plt.show()

# %%
plt.figure(

    figsize=(10,5)

)

sns.histplot(

    rules["leverage"],

    bins=30,

    kde=True

)

plt.title(

    "Leverage Distribution"

)

plt.show()

# %%
plt.figure(

    figsize=(10,5)

)

sns.histplot(

    rules["conviction"],

    bins=30,

    kde=True

)

plt.title(

    "Conviction Distribution"

)

plt.show()

# %%
recommendations = rules[

    [

        "antecedents",

        "consequents",

        "support",

        "confidence",

        "lift"

    ]

]

print("\n")

print("="*70)

print("Sample Product Recommendations")

print("="*70)

display(

    recommendations.head(20)

)
# Out:
# ======================================================================
# Sample Product Recommendations
# ======================================================================
#                       antecedents                    consequents   support  \
# 0               frozenset({soda})        frozenset({whole milk})  0.151103
# 1         frozenset({whole milk})              frozenset({soda})  0.151103
# 2               frozenset({soda})        frozenset({rolls/buns})  0.119805
# 3         frozenset({rolls/buns})              frozenset({soda})  0.119805
# 4               frozenset({soda})  frozenset({other vegetables})  0.124166
# 5   frozenset({other vegetables})              frozenset({soda})  0.124166
# 6             frozenset({yogurt})        frozenset({whole milk})  0.150590
# 7         frozenset({whole milk})            frozenset({yogurt})  0.150590
# 8               frozenset({soda})            frozenset({yogurt})  0.097486
# 9             frozenset({yogurt})              frozenset({soda})  0.097486
# 10            frozenset({yogurt})  frozenset({other vegetables})  0.120318
# 11  frozenset({other vegetables})            frozenset({yogurt})  0.120318
# 12            frozenset({yogurt})        frozenset({rolls/buns})  0.111339
# 13        frozenset({rolls/buns})            frozenset({yogurt})  0.111339
# 14           frozenset({sausage})        frozenset({whole milk})  0.106978
# 15           frozenset({sausage})              frozenset({soda})  0.077219
# 16           frozenset({sausage})            frozenset({yogurt})  0.075423
# 17           frozenset({sausage})        frozenset({rolls/buns})  0.082350
# 18           frozenset({sausage})  frozenset({other vegetables})  0.092868
# 19            frozenset({pastry})        frozenset({whole milk})  0.091072
#
#     confidence      lift
# 0     0.481997  1.051973
# 1     0.329787  1.051973
# 2     0.382160  1.092928
# 3     0.342627  1.092928
# 4     0.396072  1.051695
# 5     0.329700  1.051695
# 6     0.532185  1.161510
# 7     0.328667  1.161510
# 8     0.310966  1.098952
# 9     0.344515  1.098952
# 10    0.425204  1.129050
# 11    0.319482  1.129050
# 12    0.393472  1.125279
# 13    0.318415  1.125279
# 14    0.519303  1.133394
# 15    0.374844  1.195698
# 16    0.366127  1.293892
# 17    0.399751  1.143235
# 18    0.450809  1.197040
# 19    0.513006  1.119651

# %%
strong_rules = rules[

    rules["lift"] > 1

].sort_values(

    by="lift",

    ascending=False

)

print("\n")

print("="*70)

print("Top Strong Association Rules")

print("="*70)

display(

    strong_rules.head(20)

)
# Out:
# ======================================================================
# Top Strong Association Rules
# ======================================================================
#                             antecedents                    consequents  \
# 92                   frozenset({sugar})           frozenset({sausage})
# 271               frozenset({cat food})  frozenset({other vegetables})
# 91                   frozenset({sugar})     frozenset({bottled water})
# 244              frozenset({beverages})              frozenset({soda})
# 223  frozenset({fruit/vegetable juice})   frozenset({root vegetables})
# 178               frozenset({UHT-milk})  frozenset({other vegetables})
# 127              frozenset({chocolate})            frozenset({yogurt})
# 266                frozenset({waffles})    frozenset({tropical fruit})
# 32             frozenset({salty snack})   frozenset({root vegetables})
# 16                 frozenset({sausage})            frozenset({yogurt})
# 58                    frozenset({curd})    frozenset({tropical fruit})
# 108           frozenset({frozen meals})        frozenset({rolls/buns})
# 218            frozenset({hard cheese})  frozenset({other vegetables})
# 251                    frozenset({ham})        frozenset({whole milk})
# 230                    frozenset({oil})            frozenset({yogurt})
# 90                   frozenset({sugar})              frozenset({soda})
# 80                  frozenset({butter})            frozenset({yogurt})
# 272            frozenset({chewing gum})        frozenset({whole milk})
# 210                frozenset({napkins})        frozenset({rolls/buns})
# 159         frozenset({hamburger meat})            frozenset({yogurt})
#
#      antecedent support  consequent support   support  confidence      lift  \
# 92             0.065931            0.206003  0.020523    0.311284  1.511065
# 271            0.043869            0.376603  0.024115    0.549708  1.459646
# 91             0.065931            0.213699  0.020010    0.303502  1.420229
# 244            0.062083            0.313494  0.026167    0.421488  1.344483
# 223            0.124936            0.230631  0.038738    0.310062  1.344405
# 178            0.078502            0.376603  0.038994    0.496732  1.318979
# 127            0.086455            0.282966  0.032068    0.370920  1.310830
# 266            0.069010            0.233710  0.021036    0.304833  1.304323
# 32             0.069266            0.230631  0.020780    0.300000  1.300779
# 16             0.206003            0.282966  0.075423    0.366127  1.293892
# 58             0.120831            0.233710  0.036429    0.301486  1.290004
# 108            0.062853            0.349666  0.028220    0.448980  1.284022
# 218            0.053361            0.376603  0.025654    0.480769  1.276593
# 251            0.063366            0.458184  0.036942    0.582996  1.272407
# 230            0.055670            0.282966  0.020010    0.359447  1.270285
# 90             0.065931            0.313494  0.026167    0.396887  1.266012
# 80             0.126475            0.282966  0.044895    0.354970  1.254462
# 272            0.044638            0.458184  0.025654    0.574713  1.254328
# 210            0.081324            0.349666  0.035659    0.438486  1.254011
# 159            0.080298            0.282966  0.028476    0.354633  1.253271
#
#      representativity  leverage  conviction  zhangs_metric   jaccard  \
# 92                1.0  0.006941    1.152866       0.362088  0.081633
# 271               1.0  0.007594    1.384426       0.329351  0.060841
# 91                1.0  0.005921    1.128934       0.316773  0.077075
# 244               1.0  0.006705    1.186674       0.273180  0.074890
# 223               1.0  0.009924    1.115127       0.292752  0.122267
# 178               1.0  0.009430    1.238697       0.262440  0.093711
# 127               1.0  0.007604    1.139814       0.259565  0.095057
# 266               1.0  0.004908    1.102311       0.250613  0.074681
# 32                1.0  0.004805    1.099098       0.248438  0.074449
# 16                1.0  0.017132    1.131196       0.286069  0.182382
# 58                1.0  0.008190    1.097030       0.255706  0.114516
# 108               1.0  0.006242    1.180235       0.236033  0.073431
# 218               1.0  0.005558    1.200616       0.228878  0.063452
# 251               1.0  0.007909    1.299307       0.228571  0.076231
# 230               1.0  0.004258    1.119399       0.225319  0.062802
# 90                1.0  0.005498    1.138271       0.224949  0.074074
# 80                1.0  0.009107    1.111629       0.232215  0.123153
# 272               1.0  0.005202    1.274001       0.212234  0.053763
# 210               1.0  0.007223    1.158178       0.220490  0.090201
# 159               1.0  0.005755    1.111048       0.219732  0.085057
#
#      certainty  kulczynski
# 92    0.132596    0.205455
# 271   0.277679    0.306870
# 91    0.114209    0.198570
# 244   0.157309    0.252479
# 223   0.103241    0.239013
# 178   0.192700    0.300137
# 127   0.122664    0.242124
# 266   0.092815    0.197422
# 32    0.090163    0.195050
# 16    0.115980    0.316336
# 58    0.088448    0.228679
# 108   0.152711    0.264842
# 218   0.167094    0.274445
# 251   0.230359    0.331812
# 230   0.106663    0.215082
# 90    0.121475    0.240178
# 80    0.100419    0.256814
# 272   0.215071    0.315352
# 210   0.136575    0.270233
# 159   0.099949    0.227634

# %%
rules["Rule_Length"] = (

    rules["antecedents"].apply(len)

    +

    rules["consequents"].apply(len)

)

plt.figure(

    figsize=(8,5)

)

sns.countplot(

    x="Rule_Length",

    data=rules

)

plt.title(

    "Rule Length Distribution"

)

plt.show()

# %%
print("\n")

print("="*70)

print("Business Insights")

print("="*70)

print("- Frequently purchased products can be placed near each other.")

print("- High lift indicates strong product associations.")

print("- High confidence rules improve cross-selling opportunities.")

print("- Strong rules help build recommendation engines.")

print("- Product bundles can increase average basket value.")
# Out:
# ======================================================================
# Business Insights
# ======================================================================
# - Frequently purchased products can be placed near each other.
# - High lift indicates strong product associations.
# - High confidence rules improve cross-selling opportunities.
# - Strong rules help build recommendation engines.
# - Product bundles can increase average basket value.

# %%
print("\n")

print("="*70)

print("Apriori Algorithm Summary")

print("="*70)

print("Transactions            :", basket.shape[0])

print("Products                :", basket.shape[1])

print("Frequent Itemsets       :", len(frequent_itemsets))

print("Association Rules       :", len(rules))

print("Minimum Support         : 0.01")

print("Minimum Confidence      : 0.30")

print("="*70)
# Out:
# ======================================================================
# Apriori Algorithm Summary
# ======================================================================
# Transactions            : 3898
# Products                : 167
# Frequent Itemsets       : 586
# Association Rules       : 274
# Minimum Support         : 0.01
# Minimum Confidence      : 0.30
# ======================================================================

# %%
import joblib

# %%
joblib.dump(

    frequent_itemsets,

    "frequent_itemsets.joblib"

)
# Out:
# ['frequent_itemsets.joblib']

# %%
joblib.dump(

    rules,

    "association_rules.joblib"

)

print("\n")

print("="*70)

print("Frequent Itemsets and Association Rules Saved Successfully")

print("="*70)
# Out:
# ======================================================================
# Frequent Itemsets and Association Rules Saved Successfully
# ======================================================================

# %%
loaded_itemsets = joblib.load(

    "frequent_itemsets.joblib"

)

loaded_rules = joblib.load(

    "association_rules.joblib"

)

print("\n")

print("="*70)

print("Saved Files Loaded Successfully")

print("="*70)
# Out:
# ======================================================================
# Saved Files Loaded Successfully
# ======================================================================

# %%
def recommend_products(product_name):

    recommendations = loaded_rules[

        loaded_rules["antecedents"].apply(

            lambda x: product_name in x

        )

    ]

    recommendations = recommendations.sort_values(

        by="lift",

        ascending=False

    )

    if recommendations.empty:

        print("\nNo recommendations found.")

        return

    result = recommendations[

        [

            "antecedents",

            "consequents",

            "support",

            "confidence",

            "lift"

        ]

    ]

    return result

# %%
sample_product = basket.columns[0]

print("\n")

print("="*70)

print("Sample Product Recommendation")

print("="*70)

print("Selected Product :", sample_product)

recommendation_output = recommend_products(

    sample_product

)

display(

    recommendation_output

)
# Out:
# ======================================================================
# Sample Product Recommendation
# ======================================================================
# Selected Product : Instant food products
#
# No recommendations found.
# None

# %%
frequent_itemsets.to_csv(

    "Frequent_Itemsets.csv",

    index=False

)

print("\n")

print("="*70)

print("Frequent Itemsets Exported Successfully")

print("="*70)
# Out:
# ======================================================================
# Frequent Itemsets Exported Successfully
# ======================================================================

# %%
rules.to_csv(

    "Association_Rules.csv",

    index=False

)

print("\n")

print("="*70)

print("Association Rules Exported Successfully")

print("="*70)
# Out:
# ======================================================================
# Association Rules Exported Successfully
# ======================================================================

# %%
top_rules = rules.sort_values(

    by="lift",

    ascending=False

).head(20)

print("\n")

print("="*70)

print("Top 20 Association Rules")

print("="*70)

display(

    top_rules

)

top_rules.to_csv(

    "Top_20_Association_Rules.csv",

    index=False

)
# Out:
# ======================================================================
# Top 20 Association Rules
# ======================================================================
#                             antecedents                    consequents  \
# 92                   frozenset({sugar})           frozenset({sausage})
# 271               frozenset({cat food})  frozenset({other vegetables})
# 91                   frozenset({sugar})     frozenset({bottled water})
# 244              frozenset({beverages})              frozenset({soda})
# 223  frozenset({fruit/vegetable juice})   frozenset({root vegetables})
# 178               frozenset({UHT-milk})  frozenset({other vegetables})
# 127              frozenset({chocolate})            frozenset({yogurt})
# 266                frozenset({waffles})    frozenset({tropical fruit})
# 32             frozenset({salty snack})   frozenset({root vegetables})
# 16                 frozenset({sausage})            frozenset({yogurt})
# 58                    frozenset({curd})    frozenset({tropical fruit})
# 108           frozenset({frozen meals})        frozenset({rolls/buns})
# 218            frozenset({hard cheese})  frozenset({other vegetables})
# 251                    frozenset({ham})        frozenset({whole milk})
# 230                    frozenset({oil})            frozenset({yogurt})
# 90                   frozenset({sugar})              frozenset({soda})
# 80                  frozenset({butter})            frozenset({yogurt})
# 272            frozenset({chewing gum})        frozenset({whole milk})
# 210                frozenset({napkins})        frozenset({rolls/buns})
# 159         frozenset({hamburger meat})            frozenset({yogurt})
#
#      antecedent support  consequent support   support  confidence      lift  \
# 92             0.065931            0.206003  0.020523    0.311284  1.511065
# 271            0.043869            0.376603  0.024115    0.549708  1.459646
# 91             0.065931            0.213699  0.020010    0.303502  1.420229
# 244            0.062083            0.313494  0.026167    0.421488  1.344483
# 223            0.124936            0.230631  0.038738    0.310062  1.344405
# 178            0.078502            0.376603  0.038994    0.496732  1.318979
# 127            0.086455            0.282966  0.032068    0.370920  1.310830
# 266            0.069010            0.233710  0.021036    0.304833  1.304323
# 32             0.069266            0.230631  0.020780    0.300000  1.300779
# 16             0.206003            0.282966  0.075423    0.366127  1.293892
# 58             0.120831            0.233710  0.036429    0.301486  1.290004
# 108            0.062853            0.349666  0.028220    0.448980  1.284022
# 218            0.053361            0.376603  0.025654    0.480769  1.276593
# 251            0.063366            0.458184  0.036942    0.582996  1.272407
# 230            0.055670            0.282966  0.020010    0.359447  1.270285
# 90             0.065931            0.313494  0.026167    0.396887  1.266012
# 80             0.126475            0.282966  0.044895    0.354970  1.254462
# 272            0.044638            0.458184  0.025654    0.574713  1.254328
# 210            0.081324            0.349666  0.035659    0.438486  1.254011
# 159            0.080298            0.282966  0.028476    0.354633  1.253271
#
#      representativity  leverage  conviction  zhangs_metric   jaccard  \
# 92                1.0  0.006941    1.152866       0.362088  0.081633
# 271               1.0  0.007594    1.384426       0.329351  0.060841
# 91                1.0  0.005921    1.128934       0.316773  0.077075
# 244               1.0  0.006705    1.186674       0.273180  0.074890
# 223               1.0  0.009924    1.115127       0.292752  0.122267
# 178               1.0  0.009430    1.238697       0.262440  0.093711
# 127               1.0  0.007604    1.139814       0.259565  0.095057
# 266               1.0  0.004908    1.102311       0.250613  0.074681
# 32                1.0  0.004805    1.099098       0.248438  0.074449
# 16                1.0  0.017132    1.131196       0.286069  0.182382
# 58                1.0  0.008190    1.097030       0.255706  0.114516
# 108               1.0  0.006242    1.180235       0.236033  0.073431
# 218               1.0  0.005558    1.200616       0.228878  0.063452
# 251               1.0  0.007909    1.299307       0.228571  0.076231
# 230               1.0  0.004258    1.119399       0.225319  0.062802
# 90                1.0  0.005498    1.138271       0.224949  0.074074
# 80                1.0  0.009107    1.111629       0.232215  0.123153
# 272               1.0  0.005202    1.274001       0.212234  0.053763
# 210               1.0  0.007223    1.158178       0.220490  0.090201
# 159               1.0  0.005755    1.111048       0.219732  0.085057
#
#      certainty  kulczynski  Rule_Length
# 92    0.132596    0.205455            2
# 271   0.277679    0.306870            2
# 91    0.114209    0.198570            2
# 244   0.157309    0.252479            2
# 223   0.103241    0.239013            2
# 178   0.192700    0.300137            2
# 127   0.122664    0.242124            2
# 266   0.092815    0.197422            2
# 32    0.090163    0.195050            2
# 16    0.115980    0.316336            2
# 58    0.088448    0.228679            2
# 108   0.152711    0.264842            2
# 218   0.167094    0.274445            2
# 251   0.230359    0.331812            2
# 230   0.106663    0.215082            2
# 90    0.121475    0.240178            2
# 80    0.100419    0.256814            2
# 272   0.215071    0.315352            2
# 210   0.136575    0.270233            2
# 159   0.099949    0.227634            2

# %%
model_information = pd.DataFrame({

    "Parameter":[

        "Algorithm",

        "Minimum Support",

        "Minimum Confidence",

        "Transactions",

        "Products"

    ],

    "Value":[

        "Apriori",

        0.01,

        0.30,

        basket.shape[0],

        basket.shape[1]

    ]

})

print("\n")

print("="*70)

print("Model Information")

print("="*70)

display(

    model_information

)
# Out:
# ======================================================================
# Model Information
# ======================================================================
#             Parameter    Value
# 0           Algorithm  Apriori
# 1     Minimum Support     0.01
# 2  Minimum Confidence      0.3
# 3        Transactions     3898
# 4            Products      167

# %%
deployment_summary = pd.DataFrame({

    "File":[

        "Frequent Itemsets",

        "Association Rules",

        "Frequent Itemsets CSV",

        "Association Rules CSV",

        "Top 20 Rules"

    ],

    "Saved As":[

        "frequent_itemsets.joblib",

        "association_rules.joblib",

        "Frequent_Itemsets.csv",

        "Association_Rules.csv",

        "Top_20_Association_Rules.csv"

    ]

})

print("\n")

print("="*70)

print("Deployment Summary")

print("="*70)

display(

    deployment_summary

)
# Out:
# ======================================================================
# Deployment Summary
# ======================================================================
#                     File                      Saved As
# 0      Frequent Itemsets      frequent_itemsets.joblib
# 1      Association Rules      association_rules.joblib
# 2  Frequent Itemsets CSV         Frequent_Itemsets.csv
# 3  Association Rules CSV         Association_Rules.csv
# 4           Top 20 Rules  Top_20_Association_Rules.csv

# %%
print("\n")

print("="*70)

print("Business Insights")

print("="*70)

print("- Frequently purchased products should be placed close together.")

print("- High lift rules indicate strong product relationships.")

print("- High confidence rules improve recommendation quality.")

print("- Retailers can create combo offers using strong associations.")

print("- Association rules help increase cross-selling and average basket value.")
# Out:
# ======================================================================
# Business Insights
# ======================================================================
# - Frequently purchased products should be placed close together.
# - High lift rules indicate strong product relationships.
# - High confidence rules improve recommendation quality.
# - Retailers can create combo offers using strong associations.
# - Association rules help increase cross-selling and average basket value.

# %%
print("\n")

print("="*70)

print("Market Basket Analysis using Apriori")

print("="*70)

print("Dataset                  : Groceries Dataset")

print("Algorithm                : Apriori")

print("Transactions             :", basket.shape[0])

print("Products                 :", basket.shape[1])

print("Frequent Itemsets        :", len(frequent_itemsets))

print("Association Rules        :", len(rules))

print("Minimum Support          : 0.01")

print("Minimum Confidence       : 0.30")

print("Top Rule Lift            :", round(rules['lift'].max(),4))

print("Files Saved              : frequent_itemsets.joblib")

print("Rules Saved              : association_rules.joblib")

print("Project Status           : Deployment Ready")

print("="*70)
# Out:
# ======================================================================
# Market Basket Analysis using Apriori
# ======================================================================
# Dataset                  : Groceries Dataset
# Algorithm                : Apriori
# Transactions             : 3898
# Products                 : 167
# Frequent Itemsets        : 586
# Association Rules        : 274
# Minimum Support          : 0.01
# Minimum Confidence       : 0.30
# Top Rule Lift            : 1.5111
# Files Saved              : frequent_itemsets.joblib
# Rules Saved              : association_rules.joblib
# Project Status           : Deployment Ready
# ======================================================================

# %%
print("\n")

print("="*70)

print("Market Basket Analysis using Apriori Completed Successfully!")

print("="*70)
# Out:
# ======================================================================
# Market Basket Analysis using Apriori Completed Successfully!
# ======================================================================
